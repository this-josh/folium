# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_021c236fc64a3e17e077f1e1014e0401 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_021c236fc64a3e17e077f1e1014e0401&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_021c236fc64a3e17e077f1e1014e0401 = L.map(
#                 &quot;map_021c236fc64a3e17e077f1e1014e0401&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3bccdadf35fb9e642077fbe567c6af6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c3bccdadf35fb9e642077fbe567c6af6.addTo(map_021c236fc64a3e17e077f1e1014e0401);
#
#
#             var marker_cluster_4591e27d57cfdd3e4c6d53a7349d9c2e = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_8c400300b9e822b08cfb84ac63f85a86 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_4591e27d57cfdd3e4c6d53a7349d9c2e);
#
#
#             var icon_c7620f264274ffa4abfed4535b29174f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c400300b9e822b08cfb84ac63f85a86.setIcon(icon_c7620f264274ffa4abfed4535b29174f);
#
#
#         var popup_125b188e95232e2570315a50596a92c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd5f3789b23e92717ccdfdf087e19794 = $(`&lt;div id=&quot;html_fd5f3789b23e92717ccdfdf087e19794&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_125b188e95232e2570315a50596a92c6.setContent(html_fd5f3789b23e92717ccdfdf087e19794);
#
#
#
#         marker_8c400300b9e822b08cfb84ac63f85a86.bindPopup(popup_125b188e95232e2570315a50596a92c6)
#         ;
#
#
#
#
#             var marker_f8eafbf9292a15a50e1525c0b21d3afe = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_4591e27d57cfdd3e4c6d53a7349d9c2e);
#
#
#             var icon_4bdd98f27b259539822fee2f3edf87b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f8eafbf9292a15a50e1525c0b21d3afe.setIcon(icon_4bdd98f27b259539822fee2f3edf87b1);
#
#
#         var popup_ca4d175844a099e65a50127647fc6f21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eba8238e64e8e031f877c2916ad9b1e9 = $(`&lt;div id=&quot;html_eba8238e64e8e031f877c2916ad9b1e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ca4d175844a099e65a50127647fc6f21.setContent(html_eba8238e64e8e031f877c2916ad9b1e9);
#
#
#
#         marker_f8eafbf9292a15a50e1525c0b21d3afe.bindPopup(popup_ca4d175844a099e65a50127647fc6f21)
#         ;
#
#
#
#
#             var marker_99a698a3a647d70de53c3a1e0c449b16 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_4591e27d57cfdd3e4c6d53a7349d9c2e);
#
#
#         var popup_7b36a86a1f077f0569c4ce1599818637 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_155a391a7ece71af1e7f1cb9c267ae1b = $(`&lt;div id=&quot;html_155a391a7ece71af1e7f1cb9c267ae1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_7b36a86a1f077f0569c4ce1599818637.setContent(html_155a391a7ece71af1e7f1cb9c267ae1b);
#
#
#
#         marker_99a698a3a647d70de53c3a1e0c449b16.bindPopup(popup_7b36a86a1f077f0569c4ce1599818637)
#         ;
#
#
#
#
#             marker_cluster_4591e27d57cfdd3e4c6d53a7349d9c2e.addTo(map_021c236fc64a3e17e077f1e1014e0401);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullsc

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac3bf8f1cb113e648f6bba1c9cbe1452 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac3bf8f1cb113e648f6bba1c9cbe1452&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac3bf8f1cb113e648f6bba1c9cbe1452 = L.map(
#                 &quot;map_ac3bf8f1cb113e648f6bba1c9cbe1452&quot;,
#                 {
#                     center: [9.74, 8.83],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a844c8d1585fd3d9659b3d438f1f55ab = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a844c8d1585fd3d9659b3d438f1f55ab.addTo(map_ac3bf8f1cb113e648f6bba1c9cbe1452);
#
#
#             var marker_cluster_8a65336bf4b2d8eb30ee574afeae1c2b = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_8a65336bf4b2d8eb30ee574afeae1c2b.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_21a3333f584573bed3322bb6c93a2977 = L.marker(
#                 [49.0, -121.0],
#                 {}
#             ).addTo(marker_cluster_8a65336bf4b2d8eb30ee574afeae1c2b);
#
#
#         var popup_aca78359551585158c5a77c7f0d72884 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3116ba07c359cd4abc0f76ea628ba112 = $(`&lt;div id=&quot;html_3116ba07c359cd4abc0f76ea628ba112&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-121&lt;br&gt;lat:49&lt;/div&gt;`)[0];
#                 popup_aca78359551585158c5a77c7f0d72884.setContent(html_3116ba07c359cd4abc0f76ea628ba112);
#
#
#
#         marker_21a3333f584573bed3322bb6c93a2977.bindPopup(popup_aca78359551585158c5a77c7f0d72884)
#         ;
#
#
#
#
#             var marker_adde1b2a6285b3a016dec7697017a1ab = L.marker(
#                 [-21.0, 108.0],
#                 {}
#             ).addTo(marker_cluster_8a65336bf4b2d8eb30ee574afeae1c2b);
#
#
#         var popup_5fab18a6a90e1e645d17dff32e12916d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3222a3205695e7c383e16e1656b474d = $(`&lt;div id=&quot;html_c3222a3205695e7c383e16e1656b474d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:108&lt;br&gt;lat:-21&lt;/div&gt;`)[0];
#                 popup_5fab18a6a90e1e645d17dff32e12916d.setContent(html_c3222a3205695e7c383e16e1656b474d);
#
#
#
#         marker_adde1b2a6285b3a016dec7697017a1ab.bindPopup(popup_5fab18a6a90e1e645d17dff32e12916d)
#         ;
#
#
#
#
#             var marker_7915c0bc093a0e4563a4920263b1045e = L.marker(
#                 [68.0, 75.0],
#                 {}
#             ).addTo(marker_cluster_8a65336bf4b2d8eb30ee574afeae1c2b);
#
#
#         var popup_1fbb6464b41d89e4896ac8abf02bcb29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e9041a8d844744f92f186915f32d7d3 = $(`&lt;div id=&quot;html_2e9041a8d844744f92f186915f32d7d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:75&lt;br&gt;lat:68&lt;/div&gt;`)[0];
#                 popup_1fbb6464b41d89e4896ac8abf02bcb29.setContent(html_2e9041a8d844744f92f186915f32d7d3);
#
#
#
#         marker_7915c0bc093a0e4563a4920263b1045e.bindPopup(popup_1fbb6464b41d89e4896ac8abf02bcb29)
#         ;
#
#
#
#
#             var marker_a0fd7029b19854b922ef113f8a330865 = L.marker(
#                 [-70.0, -26.0],
#                 {}
#             ).addTo(marker_cluster_8a65336bf4b2d8eb30ee574afeae1c2b);
#
#
#         var popup_99b3b59f306fef87381cad2c28ddcfc5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d5a03aa60ba076289856583390e3d02 = $(`&lt;div id=&quot;html_3d5a03aa60ba076289856583390e3d02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-26&lt;br&gt;lat:-70&lt;/div&gt;`)[0];
#                 popup_99b3b59f306fef87381cad2c28ddcfc5.setContent(html_3d5a03aa60ba076289856583390e3d02);
#
#
#
#         marker_a0fd7029b19854b922ef113

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a84970e55359235043af12fb94395462 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a84970e55359235043af12fb94395462&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a84970e55359235043af12fb94395462 = L.map(
#                 &quot;map_a84970e55359235043af12fb94395462&quot;,
#                 {
#                     center: [9.74, 8.83],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af43e97c4a069d8f6488cfe82c0045b3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_af43e97c4a069d8f6488cfe82c0045b3.addTo(map_a84970e55359235043af12fb94395462);
#
#
#             var marker_cluster_1e748583fe13e54c98ebd1f807c42f24 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_6f445612a7bff3eb6c855b254bec40ce = L.marker(
#                 [49.0, -121.0],
#                 {}
#             ).addTo(marker_cluster_1e748583fe13e54c98ebd1f807c42f24);
#
#
#         var popup_e265d55aa97a0172d57e356c9eb4da7c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_70ffbfe6fb2c70554574da86166229ec = $(`&lt;div id=&quot;html_70ffbfe6fb2c70554574da86166229ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-121&lt;br&gt;lat:49&lt;/div&gt;`)[0];
#                 popup_e265d55aa97a0172d57e356c9eb4da7c.setContent(html_70ffbfe6fb2c70554574da86166229ec);
#
#
#
#         marker_6f445612a7bff3eb6c855b254bec40ce.bindPopup(popup_e265d55aa97a0172d57e356c9eb4da7c)
#         ;
#
#
#
#
#             var marker_91ae76883bc44996f0b998dd4b9a6d2f = L.marker(
#                 [-21.0, 108.0],
#                 {}
#             ).addTo(marker_cluster_1e748583fe13e54c98ebd1f807c42f24);
#
#
#         var popup_e0b6a19d04dda17d23124c80bcce2608 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ebcf6cf986a88af30aef859793865fa = $(`&lt;div id=&quot;html_2ebcf6cf986a88af30aef859793865fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:108&lt;br&gt;lat:-21&lt;/div&gt;`)[0];
#                 popup_e0b6a19d04dda17d23124c80bcce2608.setContent(html_2ebcf6cf986a88af30aef859793865fa);
#
#
#
#         marker_91ae76883bc44996f0b998dd4b9a6d2f.bindPopup(popup_e0b6a19d04dda17d23124c80bcce2608)
#         ;
#
#
#
#
#             var marker_213ed6ddd2ca60d6db5cdbed11520617 = L.marker(
#                 [68.0, 75.0],
#                 {}
#             ).addTo(marker_cluster_1e748583fe13e54c98ebd1f807c42f24);
#
#
#         var popup_e8ee0d37847abcf77accde08d8390ce0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f66d07f328e51b417169f86bdf22408c = $(`&lt;div id=&quot;html_f66d07f328e51b417169f86bdf22408c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:75&lt;br&gt;lat:68&lt;/div&gt;`)[0];
#                 popup_e8ee0d37847abcf77accde08d8390ce0.setContent(html_f66d07f328e51b417169f86bdf22408c);
#
#
#
#         marker_213ed6ddd2ca60d6db5cdbed11520617.bindPopup(popup_e8ee0d37847abcf77accde08d8390ce0)
#         ;
#
#
#
#
#             var marker_2d50379863743124fd49472d394600c3 = L.marker(
#                 [-70.0, -26.0],
#                 {}
#             ).addTo(marker_cluster_1e748583fe13e54c98ebd1f807c42f24);
#
#
#         var popup_003da21e359aae9b79bf6c51f01c3b42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d812cf32112df87bd1f1964a06d64c2 = $(`&lt;div id=&quot;html_2d812cf32112df87bd1f1964a06d64c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-26&lt;br&gt;lat:-70&lt;/div&gt;`)[0];
#                 popup_003da21e359aae9b79bf6c51f01c3b42.setContent(html_2d812cf32112df87bd1f1964a06d64c2);
#
#
#
#         marker_2d50379863743124fd49472d394600c3.bindPopup(popup_003da21e359aae9b79bf6c51f01c3b42)
#         ;
#
#
#
#
#             var marker_023088751ac8049cea03c76ce54f4dfc = L.marker(
#                 [-14.0, 44.0],
#                 {}
#             ).addTo(marker_cluster_1e748583fe13e54c98ebd1f807c42f24);
#
#
#         var popup_81d7ba9c9ad2df2eae5892382e3e365

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bccbb9f35b62d40f87aec6f4bf3a0ebd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bccbb9f35b62d40f87aec6f4bf3a0ebd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bccbb9f35b62d40f87aec6f4bf3a0ebd = L.map(
#                 &quot;map_bccbb9f35b62d40f87aec6f4bf3a0ebd&quot;,
#                 {
#                     center: [9.74, 8.83],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13e3b683d616651b09493d6985638e71 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_13e3b683d616651b09493d6985638e71.addTo(map_bccbb9f35b62d40f87aec6f4bf3a0ebd);
#
#
#             var fast_marker_cluster_1f95ff438832db2fca782d693510c338 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[49.0, -121.0], [-21.0, 108.0], [68.0, 75.0], [-70.0, -26.0], [-14.0, 44.0], [34.0, 73.0], [-58.0, -114.0], [-82.0, 155.0], [-68.0, -40.0], [5.0, -168.0], [28.0, 67.0], [-18.0, -108.0], [-51.0, -131.0], [-54.0, -34.0], [-70.0, -73.0], [-23.0, -176.0], [53.0, 78.0], [71.0, 144.0], [71.0, 98.0], [-84.0, 60.0], [88.0, 53.0], [-36.0, 168.0], [71.0, -51.0], [-75.0, -31.0], [-33.0, -35.0], [59.0, 141.0], [67.0, 75.0], [-66.0, -126.0], [-7.0, 23.0], [75.0, 89.0], [49.0, -155.0], [10.0, -123.0], [69.0, 95.0], [-65.0, -103.0], [2.0, -90.0], [-31.0, -55.0], [78.0, -44.0], [-2.0, 88.0], [-87.0, -114.0], [5.0, -6.0], [25.0, -7.0], [19.0, 51.0], [28.0, 92.0], [83.0, -33.0], [84.0, 22.0], [81.0, -91.0], [51.0, 108.0], [71.0, 94.0], [20.0, -21.0], [19.0, 40.0], [75.0, 0.0], [52.0, -165.0], [76.0, -37.0], [-7.0, 175.0], [51.0, 170.0], [-64.0, 119.0], [36.0, 0.0], [-41.0, -4.0], [37.0, 23.0], [-62.0, -83.0], [82.0, -123.0], [-68.0, 28.0], [21.0, 42.0], [25.0, -41.0], [-52.0, 64.0], [42.0, -75.0], [8.0, -154.0], [-32.0, -115.0], [64.0, 22.0], [23.0, 17.0], [-23.0, 161.0], [77.0, 23.0], [-65.0, 14.0], [-19.0, -49.0], [33.0, -128.0], [71.0, 162.0], [-55.0, -157.0], [30.0, -165.0], [62.0, -50.0], [6.0, 65.0], [56.0, 41.0], [59.0, 117.0], [47.0, 171.0], [28.0, -11.0], [-42.0, 153.0], [-34.0, 93.0], [84.0, -32.0], [-13.0, 76.0], [58.0, 1.0], [-57.0, 43.0], [64.0, 22.0], [-33.0, 90.0], [-77.0, 27.0], [5.0, 25.0], [-24.0, 24.0], [-68.0, 129.0], [50.0, 110.0], [70.0, 15.0], [57.0, 134.0], [-57.0, -49.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_bccbb9f35b62d40f87aec6f4bf3a0ebd);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_1f95ff438832db2fca782d693510c338.addTo(map_bccbb9f35b62d40f87aec6f4bf3a0ebd);
#
#
#             var layer_control_952befddbb6446c69a28e6192653e442_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_13e3b683d616651b09493d6985638e71,
#                 },
#                 overlays :  {
#                     &quot;macro_element_1f95ff438832db2fca782d693510c338&quot; : fast_marker_cluster_1f95ff438832db2fca782d693510c338,
#                 },
#             };
#             let layer_control_952befddbb6446c69a28e6192653e442 = L.control.layers(
#                 layer_control_952befddbb6446c69a28e6192653e442_layers.base_layers,
#                 layer_control_952befddbb6446c69a28e6192653e442_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_bccbb9f35b62d40f87aec6f4bf3a0ebd);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f77c118a26abe75cb3770131e9801f03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f77c118a26abe75cb3770131e9801f03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f77c118a26abe75cb3770131e9801f03 = L.map(
#                 &quot;map_f77c118a26abe75cb3770131e9801f03&quot;,
#                 {
#                     center: [9.74, 8.83],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8d3e42dbd96cba5317e8f5990bc404e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d8d3e42dbd96cba5317e8f5990bc404e.addTo(map_f77c118a26abe75cb3770131e9801f03);
#
#
#             var fast_marker_cluster_5ebe859e77eb85da3d89674e3f20753e = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[49.0, -121.0], [-21.0, 108.0], [68.0, 75.0], [-70.0, -26.0], [-14.0, 44.0], [34.0, 73.0], [-58.0, -114.0], [-82.0, 155.0], [-68.0, -40.0], [5.0, -168.0], [28.0, 67.0], [-18.0, -108.0], [-51.0, -131.0], [-54.0, -34.0], [-70.0, -73.0], [-23.0, -176.0], [53.0, 78.0], [71.0, 144.0], [71.0, 98.0], [-84.0, 60.0], [88.0, 53.0], [-36.0, 168.0], [71.0, -51.0], [-75.0, -31.0], [-33.0, -35.0], [59.0, 141.0], [67.0, 75.0], [-66.0, -126.0], [-7.0, 23.0], [75.0, 89.0], [49.0, -155.0], [10.0, -123.0], [69.0, 95.0], [-65.0, -103.0], [2.0, -90.0], [-31.0, -55.0], [78.0, -44.0], [-2.0, 88.0], [-87.0, -114.0], [5.0, -6.0], [25.0, -7.0], [19.0, 51.0], [28.0, 92.0], [83.0, -33.0], [84.0, 22.0], [81.0, -91.0], [51.0, 108.0], [71.0, 94.0], [20.0, -21.0], [19.0, 40.0], [75.0, 0.0], [52.0, -165.0], [76.0, -37.0], [-7.0, 175.0], [51.0, 170.0], [-64.0, 119.0], [36.0, 0.0], [-41.0, -4.0], [37.0, 23.0], [-62.0, -83.0], [82.0, -123.0], [-68.0, 28.0], [21.0, 42.0], [25.0, -41.0], [-52.0, 64.0], [42.0, -75.0], [8.0, -154.0], [-32.0, -115.0], [64.0, 22.0], [23.0, 17.0], [-23.0, 161.0], [77.0, 23.0], [-65.0, 14.0], [-19.0, -49.0], [33.0, -128.0], [71.0, 162.0], [-55.0, -157.0], [30.0, -165.0], [62.0, -50.0], [6.0, 65.0], [56.0, 41.0], [59.0, 117.0], [47.0, 171.0], [28.0, -11.0], [-42.0, 153.0], [-34.0, 93.0], [84.0, -32.0], [-13.0, 76.0], [58.0, 1.0], [-57.0, 43.0], [64.0, 22.0], [-33.0, 90.0], [-77.0, 27.0], [5.0, 25.0], [-24.0, 24.0], [-68.0, 129.0], [50.0, 110.0], [70.0, 15.0], [57.0, 134.0], [-57.0, -49.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_f77c118a26abe75cb3770131e9801f03);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_5ebe859e77eb85da3d89674e3f20753e.addTo(map_f77c118a26abe75cb3770131e9801f03);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
