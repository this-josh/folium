# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_921eeec36038e57a2700027562972517 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_921eeec36038e57a2700027562972517&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_921eeec36038e57a2700027562972517 = L.map(
#                 &quot;map_921eeec36038e57a2700027562972517&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15277c6a04d459bde3dfdfc51dbbaa11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_15277c6a04d459bde3dfdfc51dbbaa11.addTo(map_921eeec36038e57a2700027562972517);
#
#
#             var marker_cluster_9616f82e0de9266d896d6062c7a8e0a0 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_691b1290ef5743be659d08636f4163bd = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_9616f82e0de9266d896d6062c7a8e0a0);
#
#
#             var icon_f58c653d5fb1659474521f004a599797 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_691b1290ef5743be659d08636f4163bd.setIcon(icon_f58c653d5fb1659474521f004a599797);
#
#
#         var popup_72f3a542a82dfefc76f87e24ff575a2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_031e1f3da7b237c773efa88cb204bb07 = $(`&lt;div id=&quot;html_031e1f3da7b237c773efa88cb204bb07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_72f3a542a82dfefc76f87e24ff575a2a.setContent(html_031e1f3da7b237c773efa88cb204bb07);
#
#
#
#         marker_691b1290ef5743be659d08636f4163bd.bindPopup(popup_72f3a542a82dfefc76f87e24ff575a2a)
#         ;
#
#
#
#
#             var marker_506c8370831ccb968a6f97733fbe11c3 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_9616f82e0de9266d896d6062c7a8e0a0);
#
#
#             var icon_456c06a2e62ab801fed0d8761ed3d22b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_506c8370831ccb968a6f97733fbe11c3.setIcon(icon_456c06a2e62ab801fed0d8761ed3d22b);
#
#
#         var popup_70653ea60cc06d400aac45230e9bae45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cbb2c9814fce445e183b4a26a6451e5d = $(`&lt;div id=&quot;html_cbb2c9814fce445e183b4a26a6451e5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_70653ea60cc06d400aac45230e9bae45.setContent(html_cbb2c9814fce445e183b4a26a6451e5d);
#
#
#
#         marker_506c8370831ccb968a6f97733fbe11c3.bindPopup(popup_70653ea60cc06d400aac45230e9bae45)
#         ;
#
#
#
#
#             var marker_ec4ac3146601a0dda93fcaf2171a32c6 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_9616f82e0de9266d896d6062c7a8e0a0);
#
#
#         var popup_4614f1dbf8db7747abb7454edee163a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5326c381a2960a4e690253028c8252c2 = $(`&lt;div id=&quot;html_5326c381a2960a4e690253028c8252c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_4614f1dbf8db7747abb7454edee163a1.setContent(html_5326c381a2960a4e690253028c8252c2);
#
#
#
#         marker_ec4ac3146601a0dda93fcaf2171a32c6.bindPopup(popup_4614f1dbf8db7747abb7454edee163a1)
#         ;
#
#
#
#
#             marker_cluster_9616f82e0de9266d896d6062c7a8e0a0.addTo(map_921eeec36038e57a2700027562972517);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullsc

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_beba6f11619a1ccc630260dac8a6a060 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_beba6f11619a1ccc630260dac8a6a060&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_beba6f11619a1ccc630260dac8a6a060 = L.map(
#                 &quot;map_beba6f11619a1ccc630260dac8a6a060&quot;,
#                 {
#                     center: [1.29, -0.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2ca6818e95ed08e5c7932167f02632e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a2ca6818e95ed08e5c7932167f02632e.addTo(map_beba6f11619a1ccc630260dac8a6a060);
#
#
#             var marker_cluster_94a1ded0dbed6906a5ac28408ad8171b = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_94a1ded0dbed6906a5ac28408ad8171b.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_930dbcff8a711e8a6c6c3214b596256b = L.marker(
#                 [84.0, 13.0],
#                 {}
#             ).addTo(marker_cluster_94a1ded0dbed6906a5ac28408ad8171b);
#
#
#         var popup_550c4b6075d2e01e00cb514580159af0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a0201e39fd896fa54918a6197bdaf24 = $(`&lt;div id=&quot;html_1a0201e39fd896fa54918a6197bdaf24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:13&lt;br&gt;lat:84&lt;/div&gt;`)[0];
#                 popup_550c4b6075d2e01e00cb514580159af0.setContent(html_1a0201e39fd896fa54918a6197bdaf24);
#
#
#
#         marker_930dbcff8a711e8a6c6c3214b596256b.bindPopup(popup_550c4b6075d2e01e00cb514580159af0)
#         ;
#
#
#
#
#             var marker_40748f83728e6d59b9e406fa31b56ccf = L.marker(
#                 [46.0, -71.0],
#                 {}
#             ).addTo(marker_cluster_94a1ded0dbed6906a5ac28408ad8171b);
#
#
#         var popup_068acd7c3b0aff90b9d30b8035de659b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fbfee146d7d7641eea1348d17bdfbbac = $(`&lt;div id=&quot;html_fbfee146d7d7641eea1348d17bdfbbac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-71&lt;br&gt;lat:46&lt;/div&gt;`)[0];
#                 popup_068acd7c3b0aff90b9d30b8035de659b.setContent(html_fbfee146d7d7641eea1348d17bdfbbac);
#
#
#
#         marker_40748f83728e6d59b9e406fa31b56ccf.bindPopup(popup_068acd7c3b0aff90b9d30b8035de659b)
#         ;
#
#
#
#
#             var marker_d2015417a6352d0ce8f2e4b48c934c9f = L.marker(
#                 [-72.0, 74.0],
#                 {}
#             ).addTo(marker_cluster_94a1ded0dbed6906a5ac28408ad8171b);
#
#
#         var popup_db7e100d403341adc46539b3908e5210 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0e32111a9e7ac4143665bc1fc8f576f = $(`&lt;div id=&quot;html_c0e32111a9e7ac4143665bc1fc8f576f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:74&lt;br&gt;lat:-72&lt;/div&gt;`)[0];
#                 popup_db7e100d403341adc46539b3908e5210.setContent(html_c0e32111a9e7ac4143665bc1fc8f576f);
#
#
#
#         marker_d2015417a6352d0ce8f2e4b48c934c9f.bindPopup(popup_db7e100d403341adc46539b3908e5210)
#         ;
#
#
#
#
#             var marker_9a905319a0d031b64d28451e408737f0 = L.marker(
#                 [-31.0, 79.0],
#                 {}
#             ).addTo(marker_cluster_94a1ded0dbed6906a5ac28408ad8171b);
#
#
#         var popup_409123c7a9762e1101b25985a60ab4b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_747bb199a76b629bf4c9272c199808a1 = $(`&lt;div id=&quot;html_747bb199a76b629bf4c9272c199808a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:79&lt;br&gt;lat:-31&lt;/div&gt;`)[0];
#                 popup_409123c7a9762e1101b25985a60ab4b1.setContent(html_747bb199a76b629bf4c9272c199808a1);
#
#
#
#         marker_9a905319a0d031b64d28451e4087

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_434428226caf84f716d9be3574a697a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_434428226caf84f716d9be3574a697a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_434428226caf84f716d9be3574a697a0 = L.map(
#                 &quot;map_434428226caf84f716d9be3574a697a0&quot;,
#                 {
#                     center: [1.29, -0.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0d8c6a95a8d94c5ffe0b4f8b80c669d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d0d8c6a95a8d94c5ffe0b4f8b80c669d.addTo(map_434428226caf84f716d9be3574a697a0);
#
#
#             var marker_cluster_a32506bf7886dd5212f91dff445b2805 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_15e2b6908bb9335f1e63860452648d36 = L.marker(
#                 [84.0, 13.0],
#                 {}
#             ).addTo(marker_cluster_a32506bf7886dd5212f91dff445b2805);
#
#
#         var popup_f5eef72eefd8cb1baf21632d9567cc5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0198b44455d52546596af96a97ab5c7e = $(`&lt;div id=&quot;html_0198b44455d52546596af96a97ab5c7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:13&lt;br&gt;lat:84&lt;/div&gt;`)[0];
#                 popup_f5eef72eefd8cb1baf21632d9567cc5a.setContent(html_0198b44455d52546596af96a97ab5c7e);
#
#
#
#         marker_15e2b6908bb9335f1e63860452648d36.bindPopup(popup_f5eef72eefd8cb1baf21632d9567cc5a)
#         ;
#
#
#
#
#             var marker_b5b6bb8d51ad8a803c74b18efab07c09 = L.marker(
#                 [46.0, -71.0],
#                 {}
#             ).addTo(marker_cluster_a32506bf7886dd5212f91dff445b2805);
#
#
#         var popup_845fc141aeebadf86ca730d35a28b2f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e99ee4b8d7934eb2ef534481cee1dd7 = $(`&lt;div id=&quot;html_7e99ee4b8d7934eb2ef534481cee1dd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-71&lt;br&gt;lat:46&lt;/div&gt;`)[0];
#                 popup_845fc141aeebadf86ca730d35a28b2f3.setContent(html_7e99ee4b8d7934eb2ef534481cee1dd7);
#
#
#
#         marker_b5b6bb8d51ad8a803c74b18efab07c09.bindPopup(popup_845fc141aeebadf86ca730d35a28b2f3)
#         ;
#
#
#
#
#             var marker_099b2918e0fa04cad85aba6401afcf23 = L.marker(
#                 [-72.0, 74.0],
#                 {}
#             ).addTo(marker_cluster_a32506bf7886dd5212f91dff445b2805);
#
#
#         var popup_2af978dbf398ecc9eff0b7fa5b86130a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53adeae08abd55f04d7ed02be4bc418d = $(`&lt;div id=&quot;html_53adeae08abd55f04d7ed02be4bc418d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:74&lt;br&gt;lat:-72&lt;/div&gt;`)[0];
#                 popup_2af978dbf398ecc9eff0b7fa5b86130a.setContent(html_53adeae08abd55f04d7ed02be4bc418d);
#
#
#
#         marker_099b2918e0fa04cad85aba6401afcf23.bindPopup(popup_2af978dbf398ecc9eff0b7fa5b86130a)
#         ;
#
#
#
#
#             var marker_7a7b70eb84db650a08a3ee89e89a3cbe = L.marker(
#                 [-31.0, 79.0],
#                 {}
#             ).addTo(marker_cluster_a32506bf7886dd5212f91dff445b2805);
#
#
#         var popup_f67e72a5fc21b1d3fac2f91f8971e928 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fec6ecc42b3ad8d6ce5729b43df0aad1 = $(`&lt;div id=&quot;html_fec6ecc42b3ad8d6ce5729b43df0aad1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:79&lt;br&gt;lat:-31&lt;/div&gt;`)[0];
#                 popup_f67e72a5fc21b1d3fac2f91f8971e928.setContent(html_fec6ecc42b3ad8d6ce5729b43df0aad1);
#
#
#
#         marker_7a7b70eb84db650a08a3ee89e89a3cbe.bindPopup(popup_f67e72a5fc21b1d3fac2f91f8971e928)
#         ;
#
#
#
#
#             var marker_a34b955c78037a506f219fc759c2b49f = L.marker(
#                 [66.0, -148.0],
#                 {}
#             ).addTo(marker_cluster_a32506bf7886dd5212f91dff445b2805);
#
#
#         var popup_f765d71242ccaae86eca8d1afd13a357 =

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61d8f148953d6d4d44b3709b9c86e7f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61d8f148953d6d4d44b3709b9c86e7f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61d8f148953d6d4d44b3709b9c86e7f5 = L.map(
#                 &quot;map_61d8f148953d6d4d44b3709b9c86e7f5&quot;,
#                 {
#                     center: [1.29, -0.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f403bc83851579c584c5f7f379b4a172 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f403bc83851579c584c5f7f379b4a172.addTo(map_61d8f148953d6d4d44b3709b9c86e7f5);
#
#
#             var fast_marker_cluster_aecc8dfd4944e232130e928965de2b39 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[84.0, 13.0], [46.0, -71.0], [-72.0, 74.0], [-31.0, 79.0], [66.0, -148.0], [69.0, -23.0], [43.0, 52.0], [69.0, 141.0], [18.0, -39.0], [26.0, 142.0], [-60.0, 12.0], [83.0, -20.0], [-28.0, 101.0], [-85.0, -48.0], [36.0, 40.0], [84.0, 37.0], [16.0, -30.0], [-18.0, -2.0], [10.0, 63.0], [51.0, 38.0], [68.0, -38.0], [81.0, 43.0], [74.0, -177.0], [51.0, -160.0], [-6.0, 141.0], [-11.0, -85.0], [89.0, -73.0], [-61.0, 46.0], [-41.0, -154.0], [-76.0, 62.0], [-72.0, 147.0], [-27.0, -12.0], [34.0, -159.0], [39.0, 86.0], [31.0, 4.0], [37.0, -71.0], [-69.0, -173.0], [-35.0, 155.0], [-53.0, 49.0], [81.0, 35.0], [-8.0, 53.0], [50.0, 112.0], [89.0, -76.0], [-19.0, 121.0], [50.0, 122.0], [87.0, 106.0], [-27.0, -99.0], [-55.0, -162.0], [-31.0, -74.0], [-90.0, -115.0], [-52.0, -69.0], [-23.0, 69.0], [-31.0, -119.0], [-23.0, -105.0], [-59.0, 163.0], [45.0, 16.0], [-79.0, 87.0], [-34.0, 121.0], [45.0, 2.0], [-25.0, 51.0], [72.0, 147.0], [-65.0, -104.0], [-28.0, -84.0], [0.0, -121.0], [-47.0, 29.0], [-60.0, -40.0], [15.0, -136.0], [55.0, 75.0], [65.0, -28.0], [43.0, -69.0], [9.0, -121.0], [-43.0, -160.0], [38.0, 179.0], [-69.0, 173.0], [-69.0, -78.0], [-89.0, 43.0], [3.0, 68.0], [-70.0, -48.0], [69.0, -9.0], [-88.0, -39.0], [67.0, 53.0], [-59.0, 97.0], [-10.0, 110.0], [-12.0, -120.0], [-42.0, -173.0], [-34.0, 104.0], [-53.0, 31.0], [46.0, 163.0], [-6.0, 92.0], [-24.0, 82.0], [87.0, 27.0], [11.0, -26.0], [-3.0, -12.0], [13.0, -82.0], [-79.0, -92.0], [62.0, 7.0], [50.0, -171.0], [-6.0, -175.0], [-18.0, -10.0], [47.0, 68.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_61d8f148953d6d4d44b3709b9c86e7f5);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_aecc8dfd4944e232130e928965de2b39.addTo(map_61d8f148953d6d4d44b3709b9c86e7f5);
#
#
#             var layer_control_68d3b9b7090fc8810a30286301ae5cbf_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_f403bc83851579c584c5f7f379b4a172,
#                 },
#                 overlays :  {
#                     &quot;macro_element_aecc8dfd4944e232130e928965de2b39&quot; : fast_marker_cluster_aecc8dfd4944e232130e928965de2b39,
#                 },
#             };
#             let layer_control_68d3b9b7090fc8810a30286301ae5cbf = L.control.layers(
#                 layer_control_68d3b9b7090fc8810a30286301ae5cbf_layers.base_layers,
#                 layer_control_68d3b9b7090fc8810a30286301ae5cbf_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_61d8f148953d6d4d44b3709b9c86e7f5);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f11973792e16e5e483fd96fdba001b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f11973792e16e5e483fd96fdba001b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f11973792e16e5e483fd96fdba001b4 = L.map(
#                 &quot;map_9f11973792e16e5e483fd96fdba001b4&quot;,
#                 {
#                     center: [1.29, -0.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37bc3ce5d68d857c325c359ff2f13155 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_37bc3ce5d68d857c325c359ff2f13155.addTo(map_9f11973792e16e5e483fd96fdba001b4);
#
#
#             var fast_marker_cluster_6f32a8ffaa6533e1ec6d36e1663f77a2 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[84.0, 13.0], [46.0, -71.0], [-72.0, 74.0], [-31.0, 79.0], [66.0, -148.0], [69.0, -23.0], [43.0, 52.0], [69.0, 141.0], [18.0, -39.0], [26.0, 142.0], [-60.0, 12.0], [83.0, -20.0], [-28.0, 101.0], [-85.0, -48.0], [36.0, 40.0], [84.0, 37.0], [16.0, -30.0], [-18.0, -2.0], [10.0, 63.0], [51.0, 38.0], [68.0, -38.0], [81.0, 43.0], [74.0, -177.0], [51.0, -160.0], [-6.0, 141.0], [-11.0, -85.0], [89.0, -73.0], [-61.0, 46.0], [-41.0, -154.0], [-76.0, 62.0], [-72.0, 147.0], [-27.0, -12.0], [34.0, -159.0], [39.0, 86.0], [31.0, 4.0], [37.0, -71.0], [-69.0, -173.0], [-35.0, 155.0], [-53.0, 49.0], [81.0, 35.0], [-8.0, 53.0], [50.0, 112.0], [89.0, -76.0], [-19.0, 121.0], [50.0, 122.0], [87.0, 106.0], [-27.0, -99.0], [-55.0, -162.0], [-31.0, -74.0], [-90.0, -115.0], [-52.0, -69.0], [-23.0, 69.0], [-31.0, -119.0], [-23.0, -105.0], [-59.0, 163.0], [45.0, 16.0], [-79.0, 87.0], [-34.0, 121.0], [45.0, 2.0], [-25.0, 51.0], [72.0, 147.0], [-65.0, -104.0], [-28.0, -84.0], [0.0, -121.0], [-47.0, 29.0], [-60.0, -40.0], [15.0, -136.0], [55.0, 75.0], [65.0, -28.0], [43.0, -69.0], [9.0, -121.0], [-43.0, -160.0], [38.0, 179.0], [-69.0, 173.0], [-69.0, -78.0], [-89.0, 43.0], [3.0, 68.0], [-70.0, -48.0], [69.0, -9.0], [-88.0, -39.0], [67.0, 53.0], [-59.0, 97.0], [-10.0, 110.0], [-12.0, -120.0], [-42.0, -173.0], [-34.0, 104.0], [-53.0, 31.0], [46.0, 163.0], [-6.0, 92.0], [-24.0, 82.0], [87.0, 27.0], [11.0, -26.0], [-3.0, -12.0], [13.0, -82.0], [-79.0, -92.0], [62.0, 7.0], [50.0, -171.0], [-6.0, -175.0], [-18.0, -10.0], [47.0, 68.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_9f11973792e16e5e483fd96fdba001b4);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_6f32a8ffaa6533e1ec6d36e1663f77a2.addTo(map_9f11973792e16e5e483fd96fdba001b4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
