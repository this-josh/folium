# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58973975c8e271e1df2375c6aab37a80 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58973975c8e271e1df2375c6aab37a80&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58973975c8e271e1df2375c6aab37a80 = L.map(
#                 &quot;map_58973975c8e271e1df2375c6aab37a80&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29ad65c1a93769f5d8219c0b73ca5b14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_29ad65c1a93769f5d8219c0b73ca5b14.addTo(map_58973975c8e271e1df2375c6aab37a80);
#
#
#             var marker_cluster_a9fc72af208aef56d46ab0c427a43342 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_466ef95bca0bbef04d27056e8cf3c3bc = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_a9fc72af208aef56d46ab0c427a43342);
#
#
#             var icon_a525170218cb605d43360a115d9024a3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_466ef95bca0bbef04d27056e8cf3c3bc.setIcon(icon_a525170218cb605d43360a115d9024a3);
#
#
#         var popup_b8b59c64aa81a48f0f6107a760d191f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65f4e4b3f81702cf0315ac328150cd9f = $(`&lt;div id=&quot;html_65f4e4b3f81702cf0315ac328150cd9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_b8b59c64aa81a48f0f6107a760d191f8.setContent(html_65f4e4b3f81702cf0315ac328150cd9f);
#
#
#
#         marker_466ef95bca0bbef04d27056e8cf3c3bc.bindPopup(popup_b8b59c64aa81a48f0f6107a760d191f8)
#         ;
#
#
#
#
#             var marker_e4fdc935e4904a2d408f7a5df1776fa6 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_a9fc72af208aef56d46ab0c427a43342);
#
#
#             var icon_7cc82c8a570d4859f960e7063a95627e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e4fdc935e4904a2d408f7a5df1776fa6.setIcon(icon_7cc82c8a570d4859f960e7063a95627e);
#
#
#         var popup_df71f6c234e2926e2375f92ed0459f1b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_216389ac34cd4292131a5277bef7d9df = $(`&lt;div id=&quot;html_216389ac34cd4292131a5277bef7d9df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_df71f6c234e2926e2375f92ed0459f1b.setContent(html_216389ac34cd4292131a5277bef7d9df);
#
#
#
#         marker_e4fdc935e4904a2d408f7a5df1776fa6.bindPopup(popup_df71f6c234e2926e2375f92ed0459f1b)
#         ;
#
#
#
#
#             var marker_18fb11f7f4539d6b0bcd1e21a7f291db = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_a9fc72af208aef56d46ab0c427a43342);
#
#
#         var popup_54cd99aecff8d5ebd3f876e78eaa3304 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_00b2174f1748b0eff0c34f1d97969ebb = $(`&lt;div id=&quot;html_00b2174f1748b0eff0c34f1d97969ebb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_54cd99aecff8d5ebd3f876e78eaa3304.setContent(html_00b2174f1748b0eff0c34f1d97969ebb);
#
#
#
#         marker_18fb11f7f4539d6b0bcd1e21a7f291db.bindPopup(popup_54cd99aecff8d5ebd3f876e78eaa3304)
#         ;
#
#
#
#
#             marker_cluster_a9fc72af208aef56d46ab0c427a43342.addTo(map_58973975c8e271e1df2375c6aab37a80);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullsc

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32027e4168a090292c0271c545274d93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32027e4168a090292c0271c545274d93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32027e4168a090292c0271c545274d93 = L.map(
#                 &quot;map_32027e4168a090292c0271c545274d93&quot;,
#                 {
#                     center: [-3.68, -9.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ac0889af7e9cb77d0c88cf3038ae8a8 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3ac0889af7e9cb77d0c88cf3038ae8a8.addTo(map_32027e4168a090292c0271c545274d93);
#
#
#             var marker_cluster_58ad44c943200f0a789706428c687843 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_58ad44c943200f0a789706428c687843.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_7ad9ecf6dfaea5e3d101ab57932b25e1 = L.marker(
#                 [-65.0, -76.0],
#                 {}
#             ).addTo(marker_cluster_58ad44c943200f0a789706428c687843);
#
#
#         var popup_1d59c7869137ca1ce5f3daf6e407e59d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5efbf7e900f3786d59d61193801e64b = $(`&lt;div id=&quot;html_b5efbf7e900f3786d59d61193801e64b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-76&lt;br&gt;lat:-65&lt;/div&gt;`)[0];
#                 popup_1d59c7869137ca1ce5f3daf6e407e59d.setContent(html_b5efbf7e900f3786d59d61193801e64b);
#
#
#
#         marker_7ad9ecf6dfaea5e3d101ab57932b25e1.bindPopup(popup_1d59c7869137ca1ce5f3daf6e407e59d)
#         ;
#
#
#
#
#             var marker_91d634bb06777f320de9568bf10f8bff = L.marker(
#                 [33.0, -157.0],
#                 {}
#             ).addTo(marker_cluster_58ad44c943200f0a789706428c687843);
#
#
#         var popup_2e7f2f6b0176bd2fce48031af5630f04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb88b9740d05b8a753b6c83c11665f96 = $(`&lt;div id=&quot;html_fb88b9740d05b8a753b6c83c11665f96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-157&lt;br&gt;lat:33&lt;/div&gt;`)[0];
#                 popup_2e7f2f6b0176bd2fce48031af5630f04.setContent(html_fb88b9740d05b8a753b6c83c11665f96);
#
#
#
#         marker_91d634bb06777f320de9568bf10f8bff.bindPopup(popup_2e7f2f6b0176bd2fce48031af5630f04)
#         ;
#
#
#
#
#             var marker_22ed39ef8a115af12799a6fa547353d6 = L.marker(
#                 [-73.0, 116.0],
#                 {}
#             ).addTo(marker_cluster_58ad44c943200f0a789706428c687843);
#
#
#         var popup_3ac0474598236b765f1edf3913ef33bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_afd6a0f35cd89af4a5b17fb79d7df756 = $(`&lt;div id=&quot;html_afd6a0f35cd89af4a5b17fb79d7df756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:116&lt;br&gt;lat:-73&lt;/div&gt;`)[0];
#                 popup_3ac0474598236b765f1edf3913ef33bd.setContent(html_afd6a0f35cd89af4a5b17fb79d7df756);
#
#
#
#         marker_22ed39ef8a115af12799a6fa547353d6.bindPopup(popup_3ac0474598236b765f1edf3913ef33bd)
#         ;
#
#
#
#
#             var marker_7f5a755293951f383a427543799e29de = L.marker(
#                 [62.0, -118.0],
#                 {}
#             ).addTo(marker_cluster_58ad44c943200f0a789706428c687843);
#
#
#         var popup_66e2919e7984ec17bdf1a95b0f0debf8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_853f2c30cacf332921128ac5f9b70bdb = $(`&lt;div id=&quot;html_853f2c30cacf332921128ac5f9b70bdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-118&lt;br&gt;lat:62&lt;/div&gt;`)[0];
#                 popup_66e2919e7984ec17bdf1a95b0f0debf8.setContent(html_853f2c30cacf332921128ac5f9b70bdb);
#
#
#
#         marker_7f5a755293951f383

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0613c3eb6aac76ec3fe914ee2ebe17de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0613c3eb6aac76ec3fe914ee2ebe17de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0613c3eb6aac76ec3fe914ee2ebe17de = L.map(
#                 &quot;map_0613c3eb6aac76ec3fe914ee2ebe17de&quot;,
#                 {
#                     center: [-3.68, -9.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2b5f89c6f3e74878597cb08b345265e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2b5f89c6f3e74878597cb08b345265e.addTo(map_0613c3eb6aac76ec3fe914ee2ebe17de);
#
#
#             var marker_cluster_421c6ace419d76c1dd1279cf864f321e = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_2e1ff144fd0e3ecfdac5641c95cc7026 = L.marker(
#                 [-65.0, -76.0],
#                 {}
#             ).addTo(marker_cluster_421c6ace419d76c1dd1279cf864f321e);
#
#
#         var popup_652189bb9d0d692b351ededad5ed24c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fce645e6ec7cf8da8230d3c4122b2373 = $(`&lt;div id=&quot;html_fce645e6ec7cf8da8230d3c4122b2373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-76&lt;br&gt;lat:-65&lt;/div&gt;`)[0];
#                 popup_652189bb9d0d692b351ededad5ed24c2.setContent(html_fce645e6ec7cf8da8230d3c4122b2373);
#
#
#
#         marker_2e1ff144fd0e3ecfdac5641c95cc7026.bindPopup(popup_652189bb9d0d692b351ededad5ed24c2)
#         ;
#
#
#
#
#             var marker_16205cf4e0311681012f6a53c93975c8 = L.marker(
#                 [33.0, -157.0],
#                 {}
#             ).addTo(marker_cluster_421c6ace419d76c1dd1279cf864f321e);
#
#
#         var popup_5b52b1666b711cff6f7a3d1fc70390f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a456bdcfad2c245ffa2e9ad418e8e55c = $(`&lt;div id=&quot;html_a456bdcfad2c245ffa2e9ad418e8e55c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-157&lt;br&gt;lat:33&lt;/div&gt;`)[0];
#                 popup_5b52b1666b711cff6f7a3d1fc70390f7.setContent(html_a456bdcfad2c245ffa2e9ad418e8e55c);
#
#
#
#         marker_16205cf4e0311681012f6a53c93975c8.bindPopup(popup_5b52b1666b711cff6f7a3d1fc70390f7)
#         ;
#
#
#
#
#             var marker_ee278a3b11cc4fc29d2a17d90ce54d6c = L.marker(
#                 [-73.0, 116.0],
#                 {}
#             ).addTo(marker_cluster_421c6ace419d76c1dd1279cf864f321e);
#
#
#         var popup_8797133ad0f6b20f5c79cea338d9182c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d2a05ca76ebc3af199f18ecab7d193c = $(`&lt;div id=&quot;html_0d2a05ca76ebc3af199f18ecab7d193c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:116&lt;br&gt;lat:-73&lt;/div&gt;`)[0];
#                 popup_8797133ad0f6b20f5c79cea338d9182c.setContent(html_0d2a05ca76ebc3af199f18ecab7d193c);
#
#
#
#         marker_ee278a3b11cc4fc29d2a17d90ce54d6c.bindPopup(popup_8797133ad0f6b20f5c79cea338d9182c)
#         ;
#
#
#
#
#             var marker_bc949bb3a78134e59d9b547bb11cc641 = L.marker(
#                 [62.0, -118.0],
#                 {}
#             ).addTo(marker_cluster_421c6ace419d76c1dd1279cf864f321e);
#
#
#         var popup_79dde2b25b6569c0d9ba8db39db39c7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c50accb39018de94726021b3b7f9fa54 = $(`&lt;div id=&quot;html_c50accb39018de94726021b3b7f9fa54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-118&lt;br&gt;lat:62&lt;/div&gt;`)[0];
#                 popup_79dde2b25b6569c0d9ba8db39db39c7f.setContent(html_c50accb39018de94726021b3b7f9fa54);
#
#
#
#         marker_bc949bb3a78134e59d9b547bb11cc641.bindPopup(popup_79dde2b25b6569c0d9ba8db39db39c7f)
#         ;
#
#
#
#
#             var marker_31097cfff4933a625287a0ec23d4351d = L.marker(
#                 [12.0, -60.0],
#                 {}
#             ).addTo(marker_cluster_421c6ace419d76c1dd1279cf864f321e);
#
#
#         var popup_b6922fca3bb48f1c8193c3817

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_084edb711abe9d215cbfb251f45b3392 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_084edb711abe9d215cbfb251f45b3392&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_084edb711abe9d215cbfb251f45b3392 = L.map(
#                 &quot;map_084edb711abe9d215cbfb251f45b3392&quot;,
#                 {
#                     center: [-3.68, -9.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c240ecc456b4acd9763d3781c2e44b2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3c240ecc456b4acd9763d3781c2e44b2.addTo(map_084edb711abe9d215cbfb251f45b3392);
#
#
#             var fast_marker_cluster_0d16da78e91ce84a7f51f018d25883d1 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-65.0, -76.0], [33.0, -157.0], [-73.0, 116.0], [62.0, -118.0], [12.0, -60.0], [3.0, -3.0], [47.0, -19.0], [10.0, -70.0], [15.0, -152.0], [73.0, -145.0], [13.0, -126.0], [-34.0, 1.0], [-76.0, 31.0], [-73.0, -74.0], [69.0, 5.0], [21.0, 147.0], [-30.0, -108.0], [1.0, 175.0], [14.0, 35.0], [-79.0, 68.0], [6.0, -106.0], [-40.0, -68.0], [-81.0, -83.0], [-11.0, 102.0], [48.0, -107.0], [42.0, 47.0], [40.0, -175.0], [-17.0, 66.0], [-6.0, -48.0], [-47.0, 132.0], [0.0, 161.0], [7.0, -41.0], [51.0, 130.0], [14.0, 163.0], [-21.0, -62.0], [-25.0, 65.0], [78.0, -27.0], [38.0, 157.0], [-78.0, -20.0], [-89.0, 120.0], [2.0, -150.0], [-14.0, -19.0], [12.0, -170.0], [63.0, -61.0], [19.0, 43.0], [6.0, -50.0], [30.0, 148.0], [41.0, 112.0], [50.0, -29.0], [-61.0, 116.0], [-73.0, -86.0], [22.0, -135.0], [-85.0, -28.0], [22.0, 104.0], [63.0, -145.0], [-67.0, 110.0], [-65.0, 114.0], [42.0, -42.0], [-52.0, -14.0], [-30.0, 29.0], [-38.0, 9.0], [65.0, 87.0], [-75.0, -135.0], [-12.0, -83.0], [67.0, -56.0], [-20.0, 28.0], [23.0, 105.0], [-12.0, 48.0], [41.0, 111.0], [74.0, -45.0], [56.0, 57.0], [-51.0, -1.0], [59.0, -123.0], [-66.0, 36.0], [-67.0, 78.0], [46.0, -41.0], [89.0, 102.0], [-26.0, -43.0], [-34.0, -165.0], [22.0, -148.0], [24.0, -128.0], [-76.0, -33.0], [5.0, 171.0], [50.0, -164.0], [-53.0, -121.0], [-9.0, 40.0], [79.0, -130.0], [-55.0, -89.0], [-58.0, 66.0], [-61.0, -174.0], [33.0, -67.0], [25.0, -102.0], [-81.0, -3.0], [-37.0, -46.0], [49.0, 152.0], [-37.0, -14.0], [31.0, 178.0], [-70.0, -63.0], [-15.0, -164.0], [-30.0, 178.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_084edb711abe9d215cbfb251f45b3392);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_0d16da78e91ce84a7f51f018d25883d1.addTo(map_084edb711abe9d215cbfb251f45b3392);
#
#
#             var layer_control_d8437416f24cead4d1a2ce58dd59d46b_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_3c240ecc456b4acd9763d3781c2e44b2,
#                 },
#                 overlays :  {
#                     &quot;macro_element_0d16da78e91ce84a7f51f018d25883d1&quot; : fast_marker_cluster_0d16da78e91ce84a7f51f018d25883d1,
#                 },
#             };
#             let layer_control_d8437416f24cead4d1a2ce58dd59d46b = L.control.layers(
#                 layer_control_d8437416f24cead4d1a2ce58dd59d46b_layers.base_layers,
#                 layer_control_d8437416f24cead4d1a2ce58dd59d46b_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_084edb711abe9d215cbfb251f45b3392);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9de4613e1e429b1a3ca47e253de83557 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9de4613e1e429b1a3ca47e253de83557&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9de4613e1e429b1a3ca47e253de83557 = L.map(
#                 &quot;map_9de4613e1e429b1a3ca47e253de83557&quot;,
#                 {
#                     center: [-3.68, -9.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_921c7f781b6dbc4238f2d6037bb7ceff = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_921c7f781b6dbc4238f2d6037bb7ceff.addTo(map_9de4613e1e429b1a3ca47e253de83557);
#
#
#             var fast_marker_cluster_92d8476e31540ce7fb199c35535f5377 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-65.0, -76.0], [33.0, -157.0], [-73.0, 116.0], [62.0, -118.0], [12.0, -60.0], [3.0, -3.0], [47.0, -19.0], [10.0, -70.0], [15.0, -152.0], [73.0, -145.0], [13.0, -126.0], [-34.0, 1.0], [-76.0, 31.0], [-73.0, -74.0], [69.0, 5.0], [21.0, 147.0], [-30.0, -108.0], [1.0, 175.0], [14.0, 35.0], [-79.0, 68.0], [6.0, -106.0], [-40.0, -68.0], [-81.0, -83.0], [-11.0, 102.0], [48.0, -107.0], [42.0, 47.0], [40.0, -175.0], [-17.0, 66.0], [-6.0, -48.0], [-47.0, 132.0], [0.0, 161.0], [7.0, -41.0], [51.0, 130.0], [14.0, 163.0], [-21.0, -62.0], [-25.0, 65.0], [78.0, -27.0], [38.0, 157.0], [-78.0, -20.0], [-89.0, 120.0], [2.0, -150.0], [-14.0, -19.0], [12.0, -170.0], [63.0, -61.0], [19.0, 43.0], [6.0, -50.0], [30.0, 148.0], [41.0, 112.0], [50.0, -29.0], [-61.0, 116.0], [-73.0, -86.0], [22.0, -135.0], [-85.0, -28.0], [22.0, 104.0], [63.0, -145.0], [-67.0, 110.0], [-65.0, 114.0], [42.0, -42.0], [-52.0, -14.0], [-30.0, 29.0], [-38.0, 9.0], [65.0, 87.0], [-75.0, -135.0], [-12.0, -83.0], [67.0, -56.0], [-20.0, 28.0], [23.0, 105.0], [-12.0, 48.0], [41.0, 111.0], [74.0, -45.0], [56.0, 57.0], [-51.0, -1.0], [59.0, -123.0], [-66.0, 36.0], [-67.0, 78.0], [46.0, -41.0], [89.0, 102.0], [-26.0, -43.0], [-34.0, -165.0], [22.0, -148.0], [24.0, -128.0], [-76.0, -33.0], [5.0, 171.0], [50.0, -164.0], [-53.0, -121.0], [-9.0, 40.0], [79.0, -130.0], [-55.0, -89.0], [-58.0, 66.0], [-61.0, -174.0], [33.0, -67.0], [25.0, -102.0], [-81.0, -3.0], [-37.0, -46.0], [49.0, 152.0], [-37.0, -14.0], [31.0, 178.0], [-70.0, -63.0], [-15.0, -164.0], [-30.0, 178.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_9de4613e1e429b1a3ca47e253de83557);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_92d8476e31540ce7fb199c35535f5377.addTo(map_9de4613e1e429b1a3ca47e253de83557);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
