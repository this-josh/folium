# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58a129c8ebb03788f0191ceac545d375 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58a129c8ebb03788f0191ceac545d375&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58a129c8ebb03788f0191ceac545d375 = L.map(
#                 &quot;map_58a129c8ebb03788f0191ceac545d375&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98355ee0c4dbfdd2470b29f0c751b7ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_98355ee0c4dbfdd2470b29f0c751b7ac.addTo(map_58a129c8ebb03788f0191ceac545d375);
#
#
#             var marker_cluster_8c61ea9fb6aa5e5c3586363d49c60ab5 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_69327da42dcc6e23469cebd7ec1c4f65 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_8c61ea9fb6aa5e5c3586363d49c60ab5);
#
#
#             var icon_9c6a80be5bec78f43a80356ade295846 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_69327da42dcc6e23469cebd7ec1c4f65.setIcon(icon_9c6a80be5bec78f43a80356ade295846);
#
#
#         var popup_8dfb5ea0d04c08841df2601aa6f377a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cdef9c3de7df39d24b5c32142518dc1b = $(`&lt;div id=&quot;html_cdef9c3de7df39d24b5c32142518dc1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_8dfb5ea0d04c08841df2601aa6f377a3.setContent(html_cdef9c3de7df39d24b5c32142518dc1b);
#
#
#
#         marker_69327da42dcc6e23469cebd7ec1c4f65.bindPopup(popup_8dfb5ea0d04c08841df2601aa6f377a3)
#         ;
#
#
#
#
#             var marker_921cbdaeb28c9b7075169178e4cb76d5 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_8c61ea9fb6aa5e5c3586363d49c60ab5);
#
#
#             var icon_eec9159568f7ffda9d876876c7cc2d00 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_921cbdaeb28c9b7075169178e4cb76d5.setIcon(icon_eec9159568f7ffda9d876876c7cc2d00);
#
#
#         var popup_ed19f58910fb897fe71233c39685d5b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2ebe13bf914ffee91a918b222c5b33e = $(`&lt;div id=&quot;html_e2ebe13bf914ffee91a918b222c5b33e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ed19f58910fb897fe71233c39685d5b9.setContent(html_e2ebe13bf914ffee91a918b222c5b33e);
#
#
#
#         marker_921cbdaeb28c9b7075169178e4cb76d5.bindPopup(popup_ed19f58910fb897fe71233c39685d5b9)
#         ;
#
#
#
#
#             var marker_f30c6275950f67f1ef316cecb7bf897e = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_8c61ea9fb6aa5e5c3586363d49c60ab5);
#
#
#         var popup_1be86b756906e994bd6dcaf32fff8801 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b910d9e618c801260a7c7badc8d748e0 = $(`&lt;div id=&quot;html_b910d9e618c801260a7c7badc8d748e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_1be86b756906e994bd6dcaf32fff8801.setContent(html_b910d9e618c801260a7c7badc8d748e0);
#
#
#
#         marker_f30c6275950f67f1ef316cecb7bf897e.bindPopup(popup_1be86b756906e994bd6dcaf32fff8801)
#         ;
#
#
#
#
#             marker_cluster_8c61ea9fb6aa5e5c3586363d49c60ab5.addTo(map_58a129c8ebb03788f0191ceac545d375);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullsc

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c1f61d3be439cc246cc99a9942280e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c1f61d3be439cc246cc99a9942280e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c1f61d3be439cc246cc99a9942280e0 = L.map(
#                 &quot;map_7c1f61d3be439cc246cc99a9942280e0&quot;,
#                 {
#                     center: [3.28, 1.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc03a75d96dd5ff0e74f557ffb2dd6f4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dc03a75d96dd5ff0e74f557ffb2dd6f4.addTo(map_7c1f61d3be439cc246cc99a9942280e0);
#
#
#             var marker_cluster_8679ce09f71dc201006327e1d8a829a7 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_8679ce09f71dc201006327e1d8a829a7.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_77955076309f9ddf2eb928ed50d9fd68 = L.marker(
#                 [31.0, -123.0],
#                 {}
#             ).addTo(marker_cluster_8679ce09f71dc201006327e1d8a829a7);
#
#
#         var popup_8dfbdd5279cb4a1ed843490b85fbac0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2aca5074b2ab3ec7411fe19a37cb6465 = $(`&lt;div id=&quot;html_2aca5074b2ab3ec7411fe19a37cb6465&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-123&lt;br&gt;lat:31&lt;/div&gt;`)[0];
#                 popup_8dfbdd5279cb4a1ed843490b85fbac0b.setContent(html_2aca5074b2ab3ec7411fe19a37cb6465);
#
#
#
#         marker_77955076309f9ddf2eb928ed50d9fd68.bindPopup(popup_8dfbdd5279cb4a1ed843490b85fbac0b)
#         ;
#
#
#
#
#             var marker_19f7570730af05bc75ec010e290ff690 = L.marker(
#                 [-89.0, -174.0],
#                 {}
#             ).addTo(marker_cluster_8679ce09f71dc201006327e1d8a829a7);
#
#
#         var popup_d87a4c222287678a8c9d189fcfafe9c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_194ae29adc54c17cb28ee0adcb3a2336 = $(`&lt;div id=&quot;html_194ae29adc54c17cb28ee0adcb3a2336&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-174&lt;br&gt;lat:-89&lt;/div&gt;`)[0];
#                 popup_d87a4c222287678a8c9d189fcfafe9c1.setContent(html_194ae29adc54c17cb28ee0adcb3a2336);
#
#
#
#         marker_19f7570730af05bc75ec010e290ff690.bindPopup(popup_d87a4c222287678a8c9d189fcfafe9c1)
#         ;
#
#
#
#
#             var marker_2d3b4b4e92c40cdcaf61d712559b3ee3 = L.marker(
#                 [-65.0, 107.0],
#                 {}
#             ).addTo(marker_cluster_8679ce09f71dc201006327e1d8a829a7);
#
#
#         var popup_683786b6db544fb0817f4660f07cd925 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13f6362fa85f1ea3936805252c49631d = $(`&lt;div id=&quot;html_13f6362fa85f1ea3936805252c49631d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:107&lt;br&gt;lat:-65&lt;/div&gt;`)[0];
#                 popup_683786b6db544fb0817f4660f07cd925.setContent(html_13f6362fa85f1ea3936805252c49631d);
#
#
#
#         marker_2d3b4b4e92c40cdcaf61d712559b3ee3.bindPopup(popup_683786b6db544fb0817f4660f07cd925)
#         ;
#
#
#
#
#             var marker_59b9712fa55afff84dc446e12fc44184 = L.marker(
#                 [2.0, 123.0],
#                 {}
#             ).addTo(marker_cluster_8679ce09f71dc201006327e1d8a829a7);
#
#
#         var popup_28cf1af5a4a462c33e44ac9fa27aa5da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2259b2350bd482b52ca2dbcdb1d5c2e = $(`&lt;div id=&quot;html_f2259b2350bd482b52ca2dbcdb1d5c2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:123&lt;br&gt;lat:2&lt;/div&gt;`)[0];
#                 popup_28cf1af5a4a462c33e44ac9fa27aa5da.setContent(html_f2259b2350bd482b52ca2dbcdb1d5c2e);
#
#
#
#         marker_59b9712fa55afff84dc44

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3ae2dd5ec50def6ac6235e6a516fd5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3ae2dd5ec50def6ac6235e6a516fd5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3ae2dd5ec50def6ac6235e6a516fd5d = L.map(
#                 &quot;map_d3ae2dd5ec50def6ac6235e6a516fd5d&quot;,
#                 {
#                     center: [3.28, 1.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b20bed5bbae97b21f37ac8a42a7b433c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b20bed5bbae97b21f37ac8a42a7b433c.addTo(map_d3ae2dd5ec50def6ac6235e6a516fd5d);
#
#
#             var marker_cluster_e897e344db3ef873ccacafd998ff16e9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_80ab5ef664a85ec557fbdc51829b3eed = L.marker(
#                 [31.0, -123.0],
#                 {}
#             ).addTo(marker_cluster_e897e344db3ef873ccacafd998ff16e9);
#
#
#         var popup_939535ff29ae115ef7556c6ca0d276b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2684621d9867b1656c8defa04bfe990 = $(`&lt;div id=&quot;html_c2684621d9867b1656c8defa04bfe990&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-123&lt;br&gt;lat:31&lt;/div&gt;`)[0];
#                 popup_939535ff29ae115ef7556c6ca0d276b6.setContent(html_c2684621d9867b1656c8defa04bfe990);
#
#
#
#         marker_80ab5ef664a85ec557fbdc51829b3eed.bindPopup(popup_939535ff29ae115ef7556c6ca0d276b6)
#         ;
#
#
#
#
#             var marker_501552211978ad90955013d42859c52a = L.marker(
#                 [-89.0, -174.0],
#                 {}
#             ).addTo(marker_cluster_e897e344db3ef873ccacafd998ff16e9);
#
#
#         var popup_3b4adc3711d1c724a436c9fb174522a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_779456f9f7d439d9c9d394ea40c69f8a = $(`&lt;div id=&quot;html_779456f9f7d439d9c9d394ea40c69f8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-174&lt;br&gt;lat:-89&lt;/div&gt;`)[0];
#                 popup_3b4adc3711d1c724a436c9fb174522a0.setContent(html_779456f9f7d439d9c9d394ea40c69f8a);
#
#
#
#         marker_501552211978ad90955013d42859c52a.bindPopup(popup_3b4adc3711d1c724a436c9fb174522a0)
#         ;
#
#
#
#
#             var marker_86e51d6f041378fa20b38994d3e16663 = L.marker(
#                 [-65.0, 107.0],
#                 {}
#             ).addTo(marker_cluster_e897e344db3ef873ccacafd998ff16e9);
#
#
#         var popup_efd1e999e9829bd1bfa2fdc391c4b2a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56af9e59e93b6bdac64c5dac167bf3e0 = $(`&lt;div id=&quot;html_56af9e59e93b6bdac64c5dac167bf3e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:107&lt;br&gt;lat:-65&lt;/div&gt;`)[0];
#                 popup_efd1e999e9829bd1bfa2fdc391c4b2a4.setContent(html_56af9e59e93b6bdac64c5dac167bf3e0);
#
#
#
#         marker_86e51d6f041378fa20b38994d3e16663.bindPopup(popup_efd1e999e9829bd1bfa2fdc391c4b2a4)
#         ;
#
#
#
#
#             var marker_dca8cd0e8ca4a07dea61cc6c0adf45a3 = L.marker(
#                 [2.0, 123.0],
#                 {}
#             ).addTo(marker_cluster_e897e344db3ef873ccacafd998ff16e9);
#
#
#         var popup_48a60f26005eba125385dcf52391fb02 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62784508431f5109493868f753aa6055 = $(`&lt;div id=&quot;html_62784508431f5109493868f753aa6055&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:123&lt;br&gt;lat:2&lt;/div&gt;`)[0];
#                 popup_48a60f26005eba125385dcf52391fb02.setContent(html_62784508431f5109493868f753aa6055);
#
#
#
#         marker_dca8cd0e8ca4a07dea61cc6c0adf45a3.bindPopup(popup_48a60f26005eba125385dcf52391fb02)
#         ;
#
#
#
#
#             var marker_5b7bb79b696863445ce394033118e0dc = L.marker(
#                 [89.0, -75.0],
#                 {}
#             ).addTo(marker_cluster_e897e344db3ef873ccacafd998ff16e9);
#
#
#         var popup_18539ec25597e6011d03563b882ce

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5b1655cbd518ea7f9b1fb10e571e484 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5b1655cbd518ea7f9b1fb10e571e484&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5b1655cbd518ea7f9b1fb10e571e484 = L.map(
#                 &quot;map_b5b1655cbd518ea7f9b1fb10e571e484&quot;,
#                 {
#                     center: [3.28, 1.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a5e83ead4dd132ed4ed0192abefacfc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1a5e83ead4dd132ed4ed0192abefacfc.addTo(map_b5b1655cbd518ea7f9b1fb10e571e484);
#
#
#             var fast_marker_cluster_655681182665f2e7df832061a4a3898d = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[31.0, -123.0], [-89.0, -174.0], [-65.0, 107.0], [2.0, 123.0], [89.0, -75.0], [-59.0, -124.0], [84.0, -98.0], [12.0, -32.0], [68.0, -130.0], [-86.0, 62.0], [-62.0, -120.0], [-41.0, -157.0], [44.0, -120.0], [-47.0, 173.0], [53.0, 145.0], [11.0, 1.0], [43.0, -14.0], [-28.0, -154.0], [-53.0, 169.0], [4.0, 102.0], [62.0, 68.0], [-55.0, 125.0], [33.0, 109.0], [74.0, 101.0], [-29.0, -31.0], [-59.0, 83.0], [-22.0, 22.0], [-43.0, 69.0], [3.0, 84.0], [36.0, -126.0], [-82.0, 8.0], [58.0, -52.0], [-31.0, -83.0], [64.0, -125.0], [80.0, 21.0], [-76.0, -30.0], [-5.0, -85.0], [89.0, 139.0], [-33.0, 96.0], [49.0, -86.0], [-75.0, 112.0], [-76.0, 126.0], [-21.0, 8.0], [-49.0, -68.0], [-8.0, 97.0], [19.0, -28.0], [2.0, 80.0], [66.0, 71.0], [68.0, 3.0], [87.0, -106.0], [7.0, -121.0], [68.0, -44.0], [-44.0, -66.0], [-74.0, -113.0], [88.0, -138.0], [67.0, -35.0], [83.0, 36.0], [-80.0, -64.0], [-4.0, -106.0], [-1.0, -163.0], [-25.0, 108.0], [-12.0, -173.0], [56.0, -23.0], [-1.0, -107.0], [-20.0, -91.0], [48.0, 45.0], [-76.0, 95.0], [33.0, -152.0], [-54.0, -177.0], [-37.0, -5.0], [70.0, 179.0], [45.0, 164.0], [-48.0, 134.0], [-57.0, 148.0], [-70.0, 149.0], [-20.0, -142.0], [13.0, 88.0], [53.0, 52.0], [-25.0, 115.0], [57.0, 111.0], [-60.0, 138.0], [22.0, -62.0], [27.0, -122.0], [61.0, -21.0], [74.0, 0.0], [-18.0, -173.0], [-60.0, 16.0], [-21.0, 81.0], [-6.0, 133.0], [62.0, -13.0], [66.0, -53.0], [60.0, -145.0], [-30.0, -51.0], [-73.0, 175.0], [49.0, -24.0], [-46.0, -7.0], [59.0, 124.0], [35.0, 105.0], [69.0, 0.0], [-19.0, 141.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_b5b1655cbd518ea7f9b1fb10e571e484);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_655681182665f2e7df832061a4a3898d.addTo(map_b5b1655cbd518ea7f9b1fb10e571e484);
#
#
#             var layer_control_5f0683226773faa032a60ee6d680e4a6_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_1a5e83ead4dd132ed4ed0192abefacfc,
#                 },
#                 overlays :  {
#                     &quot;macro_element_655681182665f2e7df832061a4a3898d&quot; : fast_marker_cluster_655681182665f2e7df832061a4a3898d,
#                 },
#             };
#             let layer_control_5f0683226773faa032a60ee6d680e4a6 = L.control.layers(
#                 layer_control_5f0683226773faa032a60ee6d680e4a6_layers.base_layers,
#                 layer_control_5f0683226773faa032a60ee6d680e4a6_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_b5b1655cbd518ea7f9b1fb10e571e484);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00dbe80fd89727a94f81f273e8382002 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00dbe80fd89727a94f81f273e8382002&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00dbe80fd89727a94f81f273e8382002 = L.map(
#                 &quot;map_00dbe80fd89727a94f81f273e8382002&quot;,
#                 {
#                     center: [3.28, 1.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e8e7dfc8b22f078dac3b5214909bd88 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4e8e7dfc8b22f078dac3b5214909bd88.addTo(map_00dbe80fd89727a94f81f273e8382002);
#
#
#             var fast_marker_cluster_106df7b103381921d0926155c1ddba0f = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[31.0, -123.0], [-89.0, -174.0], [-65.0, 107.0], [2.0, 123.0], [89.0, -75.0], [-59.0, -124.0], [84.0, -98.0], [12.0, -32.0], [68.0, -130.0], [-86.0, 62.0], [-62.0, -120.0], [-41.0, -157.0], [44.0, -120.0], [-47.0, 173.0], [53.0, 145.0], [11.0, 1.0], [43.0, -14.0], [-28.0, -154.0], [-53.0, 169.0], [4.0, 102.0], [62.0, 68.0], [-55.0, 125.0], [33.0, 109.0], [74.0, 101.0], [-29.0, -31.0], [-59.0, 83.0], [-22.0, 22.0], [-43.0, 69.0], [3.0, 84.0], [36.0, -126.0], [-82.0, 8.0], [58.0, -52.0], [-31.0, -83.0], [64.0, -125.0], [80.0, 21.0], [-76.0, -30.0], [-5.0, -85.0], [89.0, 139.0], [-33.0, 96.0], [49.0, -86.0], [-75.0, 112.0], [-76.0, 126.0], [-21.0, 8.0], [-49.0, -68.0], [-8.0, 97.0], [19.0, -28.0], [2.0, 80.0], [66.0, 71.0], [68.0, 3.0], [87.0, -106.0], [7.0, -121.0], [68.0, -44.0], [-44.0, -66.0], [-74.0, -113.0], [88.0, -138.0], [67.0, -35.0], [83.0, 36.0], [-80.0, -64.0], [-4.0, -106.0], [-1.0, -163.0], [-25.0, 108.0], [-12.0, -173.0], [56.0, -23.0], [-1.0, -107.0], [-20.0, -91.0], [48.0, 45.0], [-76.0, 95.0], [33.0, -152.0], [-54.0, -177.0], [-37.0, -5.0], [70.0, 179.0], [45.0, 164.0], [-48.0, 134.0], [-57.0, 148.0], [-70.0, 149.0], [-20.0, -142.0], [13.0, 88.0], [53.0, 52.0], [-25.0, 115.0], [57.0, 111.0], [-60.0, 138.0], [22.0, -62.0], [27.0, -122.0], [61.0, -21.0], [74.0, 0.0], [-18.0, -173.0], [-60.0, 16.0], [-21.0, 81.0], [-6.0, 133.0], [62.0, -13.0], [66.0, -53.0], [60.0, -145.0], [-30.0, -51.0], [-73.0, 175.0], [49.0, -24.0], [-46.0, -7.0], [59.0, 124.0], [35.0, 105.0], [69.0, 0.0], [-19.0, 141.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_00dbe80fd89727a94f81f273e8382002);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_106df7b103381921d0926155c1ddba0f.addTo(map_00dbe80fd89727a94f81f273e8382002);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
