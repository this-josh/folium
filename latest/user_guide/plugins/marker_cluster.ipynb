# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42e64bdd5db22f4e282d9d30b7801d15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42e64bdd5db22f4e282d9d30b7801d15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42e64bdd5db22f4e282d9d30b7801d15 = L.map(
#                 &quot;map_42e64bdd5db22f4e282d9d30b7801d15&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30348d3f09fbbf905c85c47488f1b246 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_30348d3f09fbbf905c85c47488f1b246.addTo(map_42e64bdd5db22f4e282d9d30b7801d15);
#
#
#             var marker_cluster_d725e23b7dd4216bf831e4419880f1d2 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_eff4983d6446d648158ac054de473f37 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_d725e23b7dd4216bf831e4419880f1d2);
#
#
#             var icon_6614faeea2868eaa57a7e21506ede9af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eff4983d6446d648158ac054de473f37.setIcon(icon_6614faeea2868eaa57a7e21506ede9af);
#
#
#         var popup_ea6da5552f05839e67767332f01c3861 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_643e8656a44f6e7578c3e00fc25515e4 = $(`&lt;div id=&quot;html_643e8656a44f6e7578c3e00fc25515e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ea6da5552f05839e67767332f01c3861.setContent(html_643e8656a44f6e7578c3e00fc25515e4);
#
#
#
#         marker_eff4983d6446d648158ac054de473f37.bindPopup(popup_ea6da5552f05839e67767332f01c3861)
#         ;
#
#
#
#
#             var marker_0467ca977a605aa2ebfa630635af621c = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_d725e23b7dd4216bf831e4419880f1d2);
#
#
#             var icon_c05e0912ee8ec7f65b896eb763dff2be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0467ca977a605aa2ebfa630635af621c.setIcon(icon_c05e0912ee8ec7f65b896eb763dff2be);
#
#
#         var popup_ec0f09e5dca29f160cf3312b682971c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0098f999a52516d525d12d819b32001 = $(`&lt;div id=&quot;html_b0098f999a52516d525d12d819b32001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ec0f09e5dca29f160cf3312b682971c1.setContent(html_b0098f999a52516d525d12d819b32001);
#
#
#
#         marker_0467ca977a605aa2ebfa630635af621c.bindPopup(popup_ec0f09e5dca29f160cf3312b682971c1)
#         ;
#
#
#
#
#             var marker_a0f0e05948307ca1f909a367b6cd7edd = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_d725e23b7dd4216bf831e4419880f1d2);
#
#
#         var popup_4fafeed1a3ab89c25e60bac64bd39c61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_950aa428b25f5becf948cbf9269874c2 = $(`&lt;div id=&quot;html_950aa428b25f5becf948cbf9269874c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_4fafeed1a3ab89c25e60bac64bd39c61.setContent(html_950aa428b25f5becf948cbf9269874c2);
#
#
#
#         marker_a0f0e05948307ca1f909a367b6cd7edd.bindPopup(popup_4fafeed1a3ab89c25e60bac64bd39c61)
#         ;
#
#
#
#
#             marker_cluster_d725e23b7dd4216bf831e4419880f1d2.addTo(map_42e64bdd5db22f4e282d9d30b7801d15);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullsc

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcfb810bb3a3b9e4b665332fc78dd0cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcfb810bb3a3b9e4b665332fc78dd0cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcfb810bb3a3b9e4b665332fc78dd0cc = L.map(
#                 &quot;map_bcfb810bb3a3b9e4b665332fc78dd0cc&quot;,
#                 {
#                     center: [3.96, -1.87],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_566337e5d60c4f819446bb838c887ed5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_566337e5d60c4f819446bb838c887ed5.addTo(map_bcfb810bb3a3b9e4b665332fc78dd0cc);
#
#
#             var marker_cluster_b1a97bb00eb36df85bdce58880197605 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_b1a97bb00eb36df85bdce58880197605.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_3ab66e721a262efd2e448182933c3a48 = L.marker(
#                 [35.0, -27.0],
#                 {}
#             ).addTo(marker_cluster_b1a97bb00eb36df85bdce58880197605);
#
#
#         var popup_765d6d7d76a68f20a6ad53b9b4faca04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3762e3fedb55baf775739c7fefb41f7d = $(`&lt;div id=&quot;html_3762e3fedb55baf775739c7fefb41f7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-27&lt;br&gt;lat:35&lt;/div&gt;`)[0];
#                 popup_765d6d7d76a68f20a6ad53b9b4faca04.setContent(html_3762e3fedb55baf775739c7fefb41f7d);
#
#
#
#         marker_3ab66e721a262efd2e448182933c3a48.bindPopup(popup_765d6d7d76a68f20a6ad53b9b4faca04)
#         ;
#
#
#
#
#             var marker_a59a04fb605f317677ab42da0f3193d8 = L.marker(
#                 [58.0, -168.0],
#                 {}
#             ).addTo(marker_cluster_b1a97bb00eb36df85bdce58880197605);
#
#
#         var popup_859b9ad3508ba5c5b83620995cf07ccd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8de00569bbcee7e40f8198a0016c3e25 = $(`&lt;div id=&quot;html_8de00569bbcee7e40f8198a0016c3e25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-168&lt;br&gt;lat:58&lt;/div&gt;`)[0];
#                 popup_859b9ad3508ba5c5b83620995cf07ccd.setContent(html_8de00569bbcee7e40f8198a0016c3e25);
#
#
#
#         marker_a59a04fb605f317677ab42da0f3193d8.bindPopup(popup_859b9ad3508ba5c5b83620995cf07ccd)
#         ;
#
#
#
#
#             var marker_d0ed7d58dbd5531c65b335905d190c4e = L.marker(
#                 [-70.0, 85.0],
#                 {}
#             ).addTo(marker_cluster_b1a97bb00eb36df85bdce58880197605);
#
#
#         var popup_dcbc37fd7a34c294c6ae002281e2a7f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7008960538be91b6316c6526c615ba4a = $(`&lt;div id=&quot;html_7008960538be91b6316c6526c615ba4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:85&lt;br&gt;lat:-70&lt;/div&gt;`)[0];
#                 popup_dcbc37fd7a34c294c6ae002281e2a7f0.setContent(html_7008960538be91b6316c6526c615ba4a);
#
#
#
#         marker_d0ed7d58dbd5531c65b335905d190c4e.bindPopup(popup_dcbc37fd7a34c294c6ae002281e2a7f0)
#         ;
#
#
#
#
#             var marker_3c862c520199bd46916ca933d9e67368 = L.marker(
#                 [-88.0, 92.0],
#                 {}
#             ).addTo(marker_cluster_b1a97bb00eb36df85bdce58880197605);
#
#
#         var popup_c893eaf8ac4610f27e9ade36f8ffb1f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8363fc1ed5a876c43afc14ea23c302c5 = $(`&lt;div id=&quot;html_8363fc1ed5a876c43afc14ea23c302c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:92&lt;br&gt;lat:-88&lt;/div&gt;`)[0];
#                 popup_c893eaf8ac4610f27e9ade36f8ffb1f6.setContent(html_8363fc1ed5a876c43afc14ea23c302c5);
#
#
#
#         marker_3c862c520199bd46916ca933

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_669d4488b9163af3c83747791ef79d1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_669d4488b9163af3c83747791ef79d1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_669d4488b9163af3c83747791ef79d1b = L.map(
#                 &quot;map_669d4488b9163af3c83747791ef79d1b&quot;,
#                 {
#                     center: [3.96, -1.87],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7df27259cc4724b09240c34062e94f37 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7df27259cc4724b09240c34062e94f37.addTo(map_669d4488b9163af3c83747791ef79d1b);
#
#
#             var marker_cluster_efebedaef888ebf868f425c0af871bf7 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_b48f16f3dd9ad8a4bf8da52a8d4dcc64 = L.marker(
#                 [35.0, -27.0],
#                 {}
#             ).addTo(marker_cluster_efebedaef888ebf868f425c0af871bf7);
#
#
#         var popup_5cec3c3e7bb364cc52f4be3aa64d7a25 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3fcbd6b4f1eed66fc860a6dd35959080 = $(`&lt;div id=&quot;html_3fcbd6b4f1eed66fc860a6dd35959080&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-27&lt;br&gt;lat:35&lt;/div&gt;`)[0];
#                 popup_5cec3c3e7bb364cc52f4be3aa64d7a25.setContent(html_3fcbd6b4f1eed66fc860a6dd35959080);
#
#
#
#         marker_b48f16f3dd9ad8a4bf8da52a8d4dcc64.bindPopup(popup_5cec3c3e7bb364cc52f4be3aa64d7a25)
#         ;
#
#
#
#
#             var marker_7a09b9c85bd41bf4cdede9522ec0d3a5 = L.marker(
#                 [58.0, -168.0],
#                 {}
#             ).addTo(marker_cluster_efebedaef888ebf868f425c0af871bf7);
#
#
#         var popup_59c572c30d2bd5a1bad10e19845affd8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16901502be883861f3f6a3cff3a4edcd = $(`&lt;div id=&quot;html_16901502be883861f3f6a3cff3a4edcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-168&lt;br&gt;lat:58&lt;/div&gt;`)[0];
#                 popup_59c572c30d2bd5a1bad10e19845affd8.setContent(html_16901502be883861f3f6a3cff3a4edcd);
#
#
#
#         marker_7a09b9c85bd41bf4cdede9522ec0d3a5.bindPopup(popup_59c572c30d2bd5a1bad10e19845affd8)
#         ;
#
#
#
#
#             var marker_702150953b28fd68b24873db85bbff3e = L.marker(
#                 [-70.0, 85.0],
#                 {}
#             ).addTo(marker_cluster_efebedaef888ebf868f425c0af871bf7);
#
#
#         var popup_681bcae0c00d0b378d762fc688300427 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2eccac13a1cad2175bd38a322508e59b = $(`&lt;div id=&quot;html_2eccac13a1cad2175bd38a322508e59b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:85&lt;br&gt;lat:-70&lt;/div&gt;`)[0];
#                 popup_681bcae0c00d0b378d762fc688300427.setContent(html_2eccac13a1cad2175bd38a322508e59b);
#
#
#
#         marker_702150953b28fd68b24873db85bbff3e.bindPopup(popup_681bcae0c00d0b378d762fc688300427)
#         ;
#
#
#
#
#             var marker_f26fcb0c63f482288a43e2fd842d405a = L.marker(
#                 [-88.0, 92.0],
#                 {}
#             ).addTo(marker_cluster_efebedaef888ebf868f425c0af871bf7);
#
#
#         var popup_ddee71c2800df53d3fccae8f6b24d789 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a1563619f86d1512406fd38de95b8ff0 = $(`&lt;div id=&quot;html_a1563619f86d1512406fd38de95b8ff0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:92&lt;br&gt;lat:-88&lt;/div&gt;`)[0];
#                 popup_ddee71c2800df53d3fccae8f6b24d789.setContent(html_a1563619f86d1512406fd38de95b8ff0);
#
#
#
#         marker_f26fcb0c63f482288a43e2fd842d405a.bindPopup(popup_ddee71c2800df53d3fccae8f6b24d789)
#         ;
#
#
#
#
#             var marker_f23e5932d8f51a3325bf4493841079b8 = L.marker(
#                 [-50.0, -178.0],
#                 {}
#             ).addTo(marker_cluster_efebedaef888ebf868f425c0af871bf7);
#
#
#         var popup_4600e2cc987d1d4d35a14add21e671

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a42f9d3759736ff7711e303199be118e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a42f9d3759736ff7711e303199be118e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a42f9d3759736ff7711e303199be118e = L.map(
#                 &quot;map_a42f9d3759736ff7711e303199be118e&quot;,
#                 {
#                     center: [3.96, -1.87],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef54a6b8595c244a9de16151f75870b2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ef54a6b8595c244a9de16151f75870b2.addTo(map_a42f9d3759736ff7711e303199be118e);
#
#
#             var fast_marker_cluster_54b85bff4cb12d8033b3ec9106b2a163 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[35.0, -27.0], [58.0, -168.0], [-70.0, 85.0], [-88.0, 92.0], [-50.0, -178.0], [16.0, 125.0], [19.0, -44.0], [15.0, -154.0], [30.0, 171.0], [-70.0, -27.0], [44.0, -75.0], [79.0, -104.0], [-21.0, 158.0], [89.0, -68.0], [69.0, 25.0], [37.0, -80.0], [67.0, 107.0], [22.0, 61.0], [74.0, 2.0], [-9.0, 35.0], [-17.0, 119.0], [61.0, -46.0], [21.0, 44.0], [-33.0, 97.0], [-20.0, 18.0], [-50.0, 174.0], [70.0, 169.0], [37.0, -118.0], [-35.0, 30.0], [65.0, 31.0], [-56.0, 102.0], [-85.0, -74.0], [-31.0, 13.0], [34.0, -106.0], [-45.0, -148.0], [46.0, -3.0], [16.0, 133.0], [-72.0, 86.0], [-51.0, 45.0], [45.0, 69.0], [-50.0, 114.0], [-37.0, -128.0], [-58.0, -151.0], [-36.0, 147.0], [60.0, 17.0], [-66.0, -60.0], [-17.0, -47.0], [-75.0, 121.0], [-6.0, -52.0], [80.0, -82.0], [7.0, 31.0], [-73.0, 145.0], [47.0, -88.0], [30.0, -72.0], [28.0, -132.0], [24.0, 59.0], [-65.0, 27.0], [-64.0, -17.0], [-66.0, -115.0], [-58.0, 9.0], [27.0, 12.0], [67.0, -42.0], [4.0, 87.0], [58.0, -121.0], [-38.0, -38.0], [80.0, -116.0], [-36.0, -94.0], [46.0, -21.0], [65.0, 28.0], [-27.0, 98.0], [30.0, -17.0], [73.0, -176.0], [-27.0, 68.0], [-24.0, 141.0], [-29.0, -5.0], [32.0, -57.0], [30.0, -89.0], [-57.0, 41.0], [27.0, -86.0], [-20.0, 146.0], [-20.0, 53.0], [21.0, -20.0], [8.0, 40.0], [-30.0, -117.0], [-49.0, 103.0], [-35.0, 25.0], [43.0, -112.0], [85.0, 32.0], [-59.0, 159.0], [-46.0, -25.0], [61.0, 37.0], [-6.0, -144.0], [77.0, 14.0], [81.0, -104.0], [-49.0, -93.0], [-47.0, -58.0], [82.0, 127.0], [15.0, 83.0], [78.0, -135.0], [54.0, -108.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_a42f9d3759736ff7711e303199be118e);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_54b85bff4cb12d8033b3ec9106b2a163.addTo(map_a42f9d3759736ff7711e303199be118e);
#
#
#             var layer_control_b9e6a9664840ffc492c8f3138273b3a6_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_ef54a6b8595c244a9de16151f75870b2,
#                 },
#                 overlays :  {
#                     &quot;macro_element_54b85bff4cb12d8033b3ec9106b2a163&quot; : fast_marker_cluster_54b85bff4cb12d8033b3ec9106b2a163,
#                 },
#             };
#             let layer_control_b9e6a9664840ffc492c8f3138273b3a6 = L.control.layers(
#                 layer_control_b9e6a9664840ffc492c8f3138273b3a6_layers.base_layers,
#                 layer_control_b9e6a9664840ffc492c8f3138273b3a6_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_a42f9d3759736ff7711e303199be118e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e4817a18acada1dcce7518788749ab7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e4817a18acada1dcce7518788749ab7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e4817a18acada1dcce7518788749ab7 = L.map(
#                 &quot;map_3e4817a18acada1dcce7518788749ab7&quot;,
#                 {
#                     center: [3.96, -1.87],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b17e3a37c8d3ce78aa8d4cd70ac9e594 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b17e3a37c8d3ce78aa8d4cd70ac9e594.addTo(map_3e4817a18acada1dcce7518788749ab7);
#
#
#             var fast_marker_cluster_d8f337fb7620069a509bef73a6cc3993 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[35.0, -27.0], [58.0, -168.0], [-70.0, 85.0], [-88.0, 92.0], [-50.0, -178.0], [16.0, 125.0], [19.0, -44.0], [15.0, -154.0], [30.0, 171.0], [-70.0, -27.0], [44.0, -75.0], [79.0, -104.0], [-21.0, 158.0], [89.0, -68.0], [69.0, 25.0], [37.0, -80.0], [67.0, 107.0], [22.0, 61.0], [74.0, 2.0], [-9.0, 35.0], [-17.0, 119.0], [61.0, -46.0], [21.0, 44.0], [-33.0, 97.0], [-20.0, 18.0], [-50.0, 174.0], [70.0, 169.0], [37.0, -118.0], [-35.0, 30.0], [65.0, 31.0], [-56.0, 102.0], [-85.0, -74.0], [-31.0, 13.0], [34.0, -106.0], [-45.0, -148.0], [46.0, -3.0], [16.0, 133.0], [-72.0, 86.0], [-51.0, 45.0], [45.0, 69.0], [-50.0, 114.0], [-37.0, -128.0], [-58.0, -151.0], [-36.0, 147.0], [60.0, 17.0], [-66.0, -60.0], [-17.0, -47.0], [-75.0, 121.0], [-6.0, -52.0], [80.0, -82.0], [7.0, 31.0], [-73.0, 145.0], [47.0, -88.0], [30.0, -72.0], [28.0, -132.0], [24.0, 59.0], [-65.0, 27.0], [-64.0, -17.0], [-66.0, -115.0], [-58.0, 9.0], [27.0, 12.0], [67.0, -42.0], [4.0, 87.0], [58.0, -121.0], [-38.0, -38.0], [80.0, -116.0], [-36.0, -94.0], [46.0, -21.0], [65.0, 28.0], [-27.0, 98.0], [30.0, -17.0], [73.0, -176.0], [-27.0, 68.0], [-24.0, 141.0], [-29.0, -5.0], [32.0, -57.0], [30.0, -89.0], [-57.0, 41.0], [27.0, -86.0], [-20.0, 146.0], [-20.0, 53.0], [21.0, -20.0], [8.0, 40.0], [-30.0, -117.0], [-49.0, 103.0], [-35.0, 25.0], [43.0, -112.0], [85.0, 32.0], [-59.0, 159.0], [-46.0, -25.0], [61.0, 37.0], [-6.0, -144.0], [77.0, 14.0], [81.0, -104.0], [-49.0, -93.0], [-47.0, -58.0], [82.0, 127.0], [15.0, 83.0], [78.0, -135.0], [54.0, -108.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_3e4817a18acada1dcce7518788749ab7);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_d8f337fb7620069a509bef73a6cc3993.addTo(map_3e4817a18acada1dcce7518788749ab7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
