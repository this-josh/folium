# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edb92435bb128e18b0b21b1d4e1cfc5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edb92435bb128e18b0b21b1d4e1cfc5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edb92435bb128e18b0b21b1d4e1cfc5e = L.map(
#                 &quot;map_edb92435bb128e18b0b21b1d4e1cfc5e&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f92688f100ec016d6290ecd251b9b72 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8f92688f100ec016d6290ecd251b9b72.addTo(map_edb92435bb128e18b0b21b1d4e1cfc5e);
#
#
#             var marker_cluster_a337a91895b1ace8118cb7c3bc93b715 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_b523a74dd8795783b4a39d9a83c24f11 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_a337a91895b1ace8118cb7c3bc93b715);
#
#
#             var icon_490d9a600c6511b328ea98d442790043 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b523a74dd8795783b4a39d9a83c24f11.setIcon(icon_490d9a600c6511b328ea98d442790043);
#
#
#         var popup_03f5417dc91371a9def28c92e3fd3c5b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5539f6b748a2c9f029fc1094345add79 = $(`&lt;div id=&quot;html_5539f6b748a2c9f029fc1094345add79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_03f5417dc91371a9def28c92e3fd3c5b.setContent(html_5539f6b748a2c9f029fc1094345add79);
#
#
#
#         marker_b523a74dd8795783b4a39d9a83c24f11.bindPopup(popup_03f5417dc91371a9def28c92e3fd3c5b)
#         ;
#
#
#
#
#             var marker_e0575fca0b35b2fdbfd2716d0a3ddb10 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_a337a91895b1ace8118cb7c3bc93b715);
#
#
#             var icon_3efcad6f91c76d09b25c79a4bac626e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0575fca0b35b2fdbfd2716d0a3ddb10.setIcon(icon_3efcad6f91c76d09b25c79a4bac626e3);
#
#
#         var popup_4b5a47e7ac0e57cf5456977c3153e23e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa0072e38c901cbd2021f4a5b995593b = $(`&lt;div id=&quot;html_fa0072e38c901cbd2021f4a5b995593b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_4b5a47e7ac0e57cf5456977c3153e23e.setContent(html_fa0072e38c901cbd2021f4a5b995593b);
#
#
#
#         marker_e0575fca0b35b2fdbfd2716d0a3ddb10.bindPopup(popup_4b5a47e7ac0e57cf5456977c3153e23e)
#         ;
#
#
#
#
#             var marker_45816630a989ad3ce4c1b2ead22f1407 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_a337a91895b1ace8118cb7c3bc93b715);
#
#
#         var popup_ee060b1dd11bff768dad99082cc75423 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39c7bfc6693288a9daf7082e4d70a6b0 = $(`&lt;div id=&quot;html_39c7bfc6693288a9daf7082e4d70a6b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ee060b1dd11bff768dad99082cc75423.setContent(html_39c7bfc6693288a9daf7082e4d70a6b0);
#
#
#
#         marker_45816630a989ad3ce4c1b2ead22f1407.bindPopup(popup_ee060b1dd11bff768dad99082cc75423)
#         ;
#
#
#
#
#             marker_cluster_a337a91895b1ace8118cb7c3bc93b715.addTo(map_edb92435bb128e18b0b21b1d4e1cfc5e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullsc

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_015c7b8947422b11c766424bde0fc68e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_015c7b8947422b11c766424bde0fc68e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_015c7b8947422b11c766424bde0fc68e = L.map(
#                 &quot;map_015c7b8947422b11c766424bde0fc68e&quot;,
#                 {
#                     center: [-1.14, 7.26],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a7252ed398bb21808932242fad75ac03 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a7252ed398bb21808932242fad75ac03.addTo(map_015c7b8947422b11c766424bde0fc68e);
#
#
#             var marker_cluster_5c2a0bdc6e0814af6be10888312ccc18 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_5c2a0bdc6e0814af6be10888312ccc18.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_1261932b0c50ba37854a007e08e17382 = L.marker(
#                 [-53.0, 171.0],
#                 {}
#             ).addTo(marker_cluster_5c2a0bdc6e0814af6be10888312ccc18);
#
#
#         var popup_19358d755bc950491d3b7b86a32a7037 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ebfcf8be13e00c469c4341f2317672d = $(`&lt;div id=&quot;html_4ebfcf8be13e00c469c4341f2317672d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:171&lt;br&gt;lat:-53&lt;/div&gt;`)[0];
#                 popup_19358d755bc950491d3b7b86a32a7037.setContent(html_4ebfcf8be13e00c469c4341f2317672d);
#
#
#
#         marker_1261932b0c50ba37854a007e08e17382.bindPopup(popup_19358d755bc950491d3b7b86a32a7037)
#         ;
#
#
#
#
#             var marker_1b0b78ed65074f294dc298c5fe46170e = L.marker(
#                 [-49.0, -91.0],
#                 {}
#             ).addTo(marker_cluster_5c2a0bdc6e0814af6be10888312ccc18);
#
#
#         var popup_c261d5214b374164fb10b16ec9f3cd97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fdf8de62b08718850009e8264cce58ae = $(`&lt;div id=&quot;html_fdf8de62b08718850009e8264cce58ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-91&lt;br&gt;lat:-49&lt;/div&gt;`)[0];
#                 popup_c261d5214b374164fb10b16ec9f3cd97.setContent(html_fdf8de62b08718850009e8264cce58ae);
#
#
#
#         marker_1b0b78ed65074f294dc298c5fe46170e.bindPopup(popup_c261d5214b374164fb10b16ec9f3cd97)
#         ;
#
#
#
#
#             var marker_0aebe6664aa92891ed53879c6b4ae3ab = L.marker(
#                 [-40.0, -132.0],
#                 {}
#             ).addTo(marker_cluster_5c2a0bdc6e0814af6be10888312ccc18);
#
#
#         var popup_3f29ed03bc28d390d2ca8da04099298a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53aa685263129b79d431dd12f042d94d = $(`&lt;div id=&quot;html_53aa685263129b79d431dd12f042d94d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-132&lt;br&gt;lat:-40&lt;/div&gt;`)[0];
#                 popup_3f29ed03bc28d390d2ca8da04099298a.setContent(html_53aa685263129b79d431dd12f042d94d);
#
#
#
#         marker_0aebe6664aa92891ed53879c6b4ae3ab.bindPopup(popup_3f29ed03bc28d390d2ca8da04099298a)
#         ;
#
#
#
#
#             var marker_3aebe3b40d0accfc05f5f7f25e866ec6 = L.marker(
#                 [80.0, -18.0],
#                 {}
#             ).addTo(marker_cluster_5c2a0bdc6e0814af6be10888312ccc18);
#
#
#         var popup_ff4944c3b8186cd42035c351346f73c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb24ad837276ab68e988add1b3e3045c = $(`&lt;div id=&quot;html_bb24ad837276ab68e988add1b3e3045c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-18&lt;br&gt;lat:80&lt;/div&gt;`)[0];
#                 popup_ff4944c3b8186cd42035c351346f73c1.setContent(html_bb24ad837276ab68e988add1b3e3045c);
#
#
#
#         marker_3aebe3b40d0accfc05

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00b6ae4e7eefc5c13775162eb138f467 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00b6ae4e7eefc5c13775162eb138f467&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00b6ae4e7eefc5c13775162eb138f467 = L.map(
#                 &quot;map_00b6ae4e7eefc5c13775162eb138f467&quot;,
#                 {
#                     center: [-1.14, 7.26],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_201348a8218535393f7565a762df940d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_201348a8218535393f7565a762df940d.addTo(map_00b6ae4e7eefc5c13775162eb138f467);
#
#
#             var marker_cluster_07f55dbe52d2a782b3d87c87557265e3 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_a67d5b423f08d31c52e9ab60709fd472 = L.marker(
#                 [-53.0, 171.0],
#                 {}
#             ).addTo(marker_cluster_07f55dbe52d2a782b3d87c87557265e3);
#
#
#         var popup_27b1bfc44afe6b08d2f25272348bf3d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3da356e2e028aca5aba90a77a91e41d = $(`&lt;div id=&quot;html_a3da356e2e028aca5aba90a77a91e41d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:171&lt;br&gt;lat:-53&lt;/div&gt;`)[0];
#                 popup_27b1bfc44afe6b08d2f25272348bf3d3.setContent(html_a3da356e2e028aca5aba90a77a91e41d);
#
#
#
#         marker_a67d5b423f08d31c52e9ab60709fd472.bindPopup(popup_27b1bfc44afe6b08d2f25272348bf3d3)
#         ;
#
#
#
#
#             var marker_74c511e13d4825182cadfa3c8a099374 = L.marker(
#                 [-49.0, -91.0],
#                 {}
#             ).addTo(marker_cluster_07f55dbe52d2a782b3d87c87557265e3);
#
#
#         var popup_8aa72d5b7a56d8826d82c91aa776f040 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5a174342ecad9c53de17d6486bb4286 = $(`&lt;div id=&quot;html_e5a174342ecad9c53de17d6486bb4286&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-91&lt;br&gt;lat:-49&lt;/div&gt;`)[0];
#                 popup_8aa72d5b7a56d8826d82c91aa776f040.setContent(html_e5a174342ecad9c53de17d6486bb4286);
#
#
#
#         marker_74c511e13d4825182cadfa3c8a099374.bindPopup(popup_8aa72d5b7a56d8826d82c91aa776f040)
#         ;
#
#
#
#
#             var marker_e45528ecdaf11df827d068ed15d21529 = L.marker(
#                 [-40.0, -132.0],
#                 {}
#             ).addTo(marker_cluster_07f55dbe52d2a782b3d87c87557265e3);
#
#
#         var popup_796e0c48ba22ced832f15f4ca351882a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef84f5dbe5ab9ceb6eee198bd315eb83 = $(`&lt;div id=&quot;html_ef84f5dbe5ab9ceb6eee198bd315eb83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-132&lt;br&gt;lat:-40&lt;/div&gt;`)[0];
#                 popup_796e0c48ba22ced832f15f4ca351882a.setContent(html_ef84f5dbe5ab9ceb6eee198bd315eb83);
#
#
#
#         marker_e45528ecdaf11df827d068ed15d21529.bindPopup(popup_796e0c48ba22ced832f15f4ca351882a)
#         ;
#
#
#
#
#             var marker_95c714f449ba32dfaed361d616799c91 = L.marker(
#                 [80.0, -18.0],
#                 {}
#             ).addTo(marker_cluster_07f55dbe52d2a782b3d87c87557265e3);
#
#
#         var popup_b020693b97d5af538329f0d73f72b61b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b19fcd481aa068edad7a15522125df6f = $(`&lt;div id=&quot;html_b19fcd481aa068edad7a15522125df6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-18&lt;br&gt;lat:80&lt;/div&gt;`)[0];
#                 popup_b020693b97d5af538329f0d73f72b61b.setContent(html_b19fcd481aa068edad7a15522125df6f);
#
#
#
#         marker_95c714f449ba32dfaed361d616799c91.bindPopup(popup_b020693b97d5af538329f0d73f72b61b)
#         ;
#
#
#
#
#             var marker_bc34f474d55914038f1b88f5fb5db764 = L.marker(
#                 [6.0, 32.0],
#                 {}
#             ).addTo(marker_cluster_07f55dbe52d2a782b3d87c87557265e3);
#
#
#         var popup_88f5c406b3ae90044f004a779fab

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_901bca1c071bfd7f6b215efb85f69e5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_901bca1c071bfd7f6b215efb85f69e5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_901bca1c071bfd7f6b215efb85f69e5b = L.map(
#                 &quot;map_901bca1c071bfd7f6b215efb85f69e5b&quot;,
#                 {
#                     center: [-1.14, 7.26],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55894e1a63591b54d2f398718719fd9a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_55894e1a63591b54d2f398718719fd9a.addTo(map_901bca1c071bfd7f6b215efb85f69e5b);
#
#
#             var fast_marker_cluster_b62a91b17f29377221b45e25ce9720c8 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-53.0, 171.0], [-49.0, -91.0], [-40.0, -132.0], [80.0, -18.0], [6.0, 32.0], [-42.0, -7.0], [20.0, -130.0], [-53.0, 136.0], [-64.0, -99.0], [13.0, 113.0], [34.0, -27.0], [38.0, -76.0], [65.0, 159.0], [31.0, -58.0], [77.0, -42.0], [-90.0, 96.0], [-51.0, 43.0], [72.0, -140.0], [-19.0, -60.0], [-80.0, -102.0], [58.0, 163.0], [-10.0, 97.0], [-29.0, 61.0], [-5.0, 34.0], [78.0, 27.0], [-44.0, -38.0], [26.0, -16.0], [56.0, 135.0], [-16.0, 74.0], [82.0, -91.0], [-9.0, 49.0], [0.0, -64.0], [-86.0, 122.0], [-16.0, -176.0], [-11.0, -180.0], [65.0, -12.0], [-4.0, 1.0], [-57.0, -11.0], [-73.0, 152.0], [-27.0, -15.0], [40.0, 142.0], [7.0, 75.0], [-57.0, 41.0], [42.0, -21.0], [-34.0, 154.0], [7.0, -166.0], [56.0, 116.0], [13.0, 16.0], [-39.0, 141.0], [38.0, -74.0], [-85.0, 116.0], [82.0, 129.0], [49.0, -59.0], [88.0, -150.0], [-46.0, 108.0], [13.0, 85.0], [8.0, -21.0], [44.0, -91.0], [55.0, -38.0], [-77.0, 83.0], [-11.0, -63.0], [-64.0, 5.0], [23.0, 160.0], [-66.0, 157.0], [59.0, -50.0], [-44.0, 15.0], [80.0, -94.0], [-85.0, -86.0], [-8.0, -3.0], [-16.0, 78.0], [-80.0, -37.0], [42.0, -75.0], [38.0, 77.0], [-20.0, -111.0], [14.0, 130.0], [-57.0, 85.0], [7.0, 144.0], [88.0, 101.0], [89.0, -123.0], [-78.0, 50.0], [88.0, 68.0], [-64.0, -117.0], [-82.0, 34.0], [13.0, 42.0], [-38.0, -82.0], [-26.0, -64.0], [-74.0, -171.0], [79.0, 119.0], [-65.0, 177.0], [-45.0, -152.0], [-85.0, -160.0], [74.0, 59.0], [25.0, 6.0], [85.0, -21.0], [-61.0, -26.0], [-9.0, 115.0], [23.0, 111.0], [57.0, -92.0], [-77.0, -59.0], [80.0, -87.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_901bca1c071bfd7f6b215efb85f69e5b);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_b62a91b17f29377221b45e25ce9720c8.addTo(map_901bca1c071bfd7f6b215efb85f69e5b);
#
#
#             var layer_control_06ac8e0ccb100c6662cb68fdd8b962d4_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_55894e1a63591b54d2f398718719fd9a,
#                 },
#                 overlays :  {
#                     &quot;macro_element_b62a91b17f29377221b45e25ce9720c8&quot; : fast_marker_cluster_b62a91b17f29377221b45e25ce9720c8,
#                 },
#             };
#             let layer_control_06ac8e0ccb100c6662cb68fdd8b962d4 = L.control.layers(
#                 layer_control_06ac8e0ccb100c6662cb68fdd8b962d4_layers.base_layers,
#                 layer_control_06ac8e0ccb100c6662cb68fdd8b962d4_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_901bca1c071bfd7f6b215efb85f69e5b);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f244fcb82e3947942900e16914a1f12 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f244fcb82e3947942900e16914a1f12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f244fcb82e3947942900e16914a1f12 = L.map(
#                 &quot;map_9f244fcb82e3947942900e16914a1f12&quot;,
#                 {
#                     center: [-1.14, 7.26],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96d107f8ce241412b86e1aa77f773ecd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_96d107f8ce241412b86e1aa77f773ecd.addTo(map_9f244fcb82e3947942900e16914a1f12);
#
#
#             var fast_marker_cluster_47c454f48a82f6d4bec7f9dd6780ae24 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-53.0, 171.0], [-49.0, -91.0], [-40.0, -132.0], [80.0, -18.0], [6.0, 32.0], [-42.0, -7.0], [20.0, -130.0], [-53.0, 136.0], [-64.0, -99.0], [13.0, 113.0], [34.0, -27.0], [38.0, -76.0], [65.0, 159.0], [31.0, -58.0], [77.0, -42.0], [-90.0, 96.0], [-51.0, 43.0], [72.0, -140.0], [-19.0, -60.0], [-80.0, -102.0], [58.0, 163.0], [-10.0, 97.0], [-29.0, 61.0], [-5.0, 34.0], [78.0, 27.0], [-44.0, -38.0], [26.0, -16.0], [56.0, 135.0], [-16.0, 74.0], [82.0, -91.0], [-9.0, 49.0], [0.0, -64.0], [-86.0, 122.0], [-16.0, -176.0], [-11.0, -180.0], [65.0, -12.0], [-4.0, 1.0], [-57.0, -11.0], [-73.0, 152.0], [-27.0, -15.0], [40.0, 142.0], [7.0, 75.0], [-57.0, 41.0], [42.0, -21.0], [-34.0, 154.0], [7.0, -166.0], [56.0, 116.0], [13.0, 16.0], [-39.0, 141.0], [38.0, -74.0], [-85.0, 116.0], [82.0, 129.0], [49.0, -59.0], [88.0, -150.0], [-46.0, 108.0], [13.0, 85.0], [8.0, -21.0], [44.0, -91.0], [55.0, -38.0], [-77.0, 83.0], [-11.0, -63.0], [-64.0, 5.0], [23.0, 160.0], [-66.0, 157.0], [59.0, -50.0], [-44.0, 15.0], [80.0, -94.0], [-85.0, -86.0], [-8.0, -3.0], [-16.0, 78.0], [-80.0, -37.0], [42.0, -75.0], [38.0, 77.0], [-20.0, -111.0], [14.0, 130.0], [-57.0, 85.0], [7.0, 144.0], [88.0, 101.0], [89.0, -123.0], [-78.0, 50.0], [88.0, 68.0], [-64.0, -117.0], [-82.0, 34.0], [13.0, 42.0], [-38.0, -82.0], [-26.0, -64.0], [-74.0, -171.0], [79.0, 119.0], [-65.0, 177.0], [-45.0, -152.0], [-85.0, -160.0], [74.0, 59.0], [25.0, 6.0], [85.0, -21.0], [-61.0, -26.0], [-9.0, 115.0], [23.0, 111.0], [57.0, -92.0], [-77.0, -59.0], [80.0, -87.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_9f244fcb82e3947942900e16914a1f12);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_47c454f48a82f6d4bec7f9dd6780ae24.addTo(map_9f244fcb82e3947942900e16914a1f12);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
