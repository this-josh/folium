# %% [markdown]
# # TagFilterButton

# %%
import os
import folium

# %%
import numpy as np
import random

# Generate base data
data = (np.random.normal(size=(100, 2)) * np.array([[1, 1]]) +
                np.array([[48, 5]]))
# Generate the data to segment by (levels of another pandas column in practical usage)
categories = ['category{}'.format(i+1) for i in range(5)]
category_column = [random.choice(categories) for i in range(len(data))]

# %% [markdown]
# Create markers, and add tags to each marker. There can be multiple tags per marker, but in this example we add just one.
#
# Then, create the `TagFilterButton` object and let it know which tags you want to filter on.

# %%
from folium.plugins import TagFilterButton

# Create map and add the data with additional parameter tags as the segmentation
m = folium.Map([48., 5.], zoom_start=7)
for i, latlng in enumerate(data):
    category = category_column[i]
    folium.Marker(
        tuple(latlng),
        tags=[category]
    ).add_to(m)

TagFilterButton(categories).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2738eb644c09741e7c1786c1e4d09e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/css-ripple-effect@1.0.5/dist/ripple.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2738eb644c09741e7c1786c1e4d09e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2738eb644c09741e7c1786c1e4d09e3 = L.map(
#                 &quot;map_b2738eb644c09741e7c1786c1e4d09e3&quot;,
#                 {
#                     center: [48.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9b1ada26e9894f2803be2b248f11418 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c9b1ada26e9894f2803be2b248f11418.addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_62c826c2d004f72c709a646c7276a237 = L.marker(
#                 [48.574411429818284, 4.986561873779649],
#                 {&quot;tags&quot;: [&quot;category1&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_36cd1a3870442572894872ed890200f6 = L.marker(
#                 [46.97775818713049, 4.599516073631422],
#                 {&quot;tags&quot;: [&quot;category5&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_e2b5ce2d72b3b2c626e5072319620d89 = L.marker(
#                 [46.07218887188191, 6.6024858634285994],
#                 {&quot;tags&quot;: [&quot;category5&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_22d49c62e01e98558d60f8c786a04510 = L.marker(
#                 [47.76348606066018, 5.35994266352716],
#                 {&quot;tags&quot;: [&quot;category5&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_e4b4ec3aeefcd3054a79ab9f1da3087a = L.marker(
#                 [48.27456360324728, 5.34803868963037],
#                 {&quot;tags&quot;: [&quot;category2&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_8ae9fcb665c355e955e0138b090ae9ae = L.marker(
#                 [48.12073613352332, 4.209223524531718],
#                 {&quot;tags&quot;: [&quot;category2&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_96cabb20ebeacd2720b6650384e0c4cc = L.marker(
#                 [48.812514107459, 4.531622986578754],
#                 {&quot;tags&quot;: [&quot;category5&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_b73cc004a25ec7a8cb00b5eba4cdd92d = L.marker(
#                 [47.95169589296066, 3.471262545988967],
#                 {&quot;tags&quot;: [&quot;category1&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_01f383f9094d48dadfbe9aebd96555a7 = L.marker(
#                 [49.28247861319155, 5.527447630894973],
#                 {&quot;tags&quot;: [&quot;category1&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_0cfd83c244d84fed9c6c943247762516 = L.marker(
#                 [46.6957041528236, 6.330080226966334],
#                 {&quot;tags&quot;: [&quot;category2&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_f8e59952f834abf6623f26893e8fe25a = L.marker(
#                 [48.71889261304261, 2.457794683530318],
#                 {&quot;tags&quot;: [&quot;category1&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_dff81a82803c57b0fbb19c3066251063 = L.marker(
#                 [46.78128841800464, 4.721255390215205],
#                 {&quot;tags&quot;: [&quot;category4&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_9084db34a537425535fcd1f143c187c0 = L.marker(
#                 [49.16460198892564, 5.11357582193166],
#                 {&quot;tags&quot;: [&quot;category1&quot;]}
#             ).addTo(map_b2738eb644c09741e7c1786c1e4d09e3);
#
#
#             var marker_a4e618f3e3f2e3a6cf44541bc12a3513 = L.marker(
#                 [48.05388745916913, 4.308886946279245],
#                 {&quot;tags&
